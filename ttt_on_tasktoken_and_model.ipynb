# %% [markdown]
# # VARC (Vision ARC) — Offline Training + Test-Time Training on Kaggle
#
# This notebook runs the **official, unmodified** code from [lillian039/VARC](https://github.com/lillian039/VARC),
# the reference implementation for the paper *["ARC Is a Vision Problem!"](https://arxiv.org/abs/2511.14761)*
# (Hu et al.). It:
#
# 1. Clones the repo as-is (no code edits — same `ARC_ViT.py`, `ARC_loader.py`, `offline_train_ARC.py`,
#    `test_time_train_ARC.py` you already have).
# 2. Runs **offline training** of the ViT model on the ARC-AGI-1 training set (+ optional RE-ARC data).
# 3. Builds the augmented per-task **test-time-training (TTT)** dataset and runs TTT + inference on a
#    configurable set of ARC-AGI-1 evaluation tasks.
# 4. Aggregates predictions into Pass@1 / Pass@2 / Oracle scores, the same metrics the repo's own
#    `analysis.py` reports.
#
# ### About scale
# The authors trained on **8×H200 GPUs** (offline: ~5h; TTT: all 400 eval tasks run in parallel across
# 8 GPUs). Kaggle gives you a **single GPU** (T4/P100, ~9h/session, ~30h/week quota). The code is left
# completely untouched — only the **command-line hyperparameters** in the Config cell below are yours to
# tune. Everything is exposed there: epochs, batch size, RE-ARC usage, number of TTT tasks, etc.
# Defaults are set to the values from the repo's own `script/*.sh` files; lower `OFFLINE_EPOCHS`,
# `REARC_LIMIT`, and `NUM_TTT_TASKS` for a quick smoke test.

# %% [markdown]
# ## 0. Check GPU
# Make sure the Kaggle notebook's **Accelerator** is set to a GPU (Settings → Accelerator → GPU T4 x2 / P100).

# %%
# !nvidia-smi
import torch
print("torch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Mon Aug  3 09:11:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   46C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# torch: 2.10.0+cu128 | CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# ## 1. Clone the official VARC repo (unmodified)
#
# The ARC-AGI-1 and RE-ARC raw data ship inside the repo itself, so no separate data download is needed.

# %%
import os, subprocess

WORK_DIR = "/kaggle/working"
REPO_DIR = f"{WORK_DIR}/VARC"

os.chdir(WORK_DIR)
if not os.path.isdir(REPO_DIR):
    result = subprocess.run(
        ["git", "clone", "--depth", "1", "https://github.com/lillian039/VARC.git"],
        cwd=WORK_DIR, capture_output=True, text=True,
    )
    print(result.stdout)
    print(result.stderr)
    if result.returncode != 0 or not os.path.isdir(REPO_DIR):
        raise RuntimeError(
            "git clone failed, so the repo was not created. The #1 cause on Kaggle is that "
            "'Internet' is turned off for this notebook. Fix: Notebook Settings (top right, "
            "three-dot menu or side panel) -> Internet -> toggle ON, then re-run this cell. "
            "You may also need to verify your Kaggle account (phone verification) to enable internet access."
        )
else:
    print("Repo already present, skipping clone.")

os.chdir(REPO_DIR)
# !ls
# Out:
# Cloning into 'VARC'...
# Updating files:  85% (2041/2380)
# Updating files:  86% (2047/2380)
# Updating files:  87% (2071/2380)
# Updating files:  88% (2095/2380)
# Updating files:  89% (2119/2380)
# Updating files:  90% (2142/2380)
# Updating files:  91% (2166/2380)
# Updating files:  92% (2190/2380)
# Updating files:  92% (2212/2380)
# Updating files:  93% (2214/2380)
# Updating files:  94% (2238/2380)
# Updating files:  95% (2261/2380)
# Updating files:  96% (2285/2380)
# Updating files:  97% (2309/2380)
# Updating files:  98% (2333/2380)
# Updating files:  99% (2357/2380)
# Updating files: 100% (2380/2380)
# Updating files: 100% (2380/2380), done.
#
# analysis.py	 LICENSE	       README.md	 src
# assets		 offline_train_ARC.py  requirements.txt  test_time_train_ARC.py
# augment_data.py  raw_data	       script		 utils

# %% [markdown]
# ## 2. Install dependencies
#
# Kaggle already ships a CUDA-enabled PyTorch + NumPy, so we deliberately **don't** force the exact
# `torch==2.7.0` / `numpy==2.2.6` pins from `requirements.txt` (doing so can break the pre-configured GPU
# driver stack). Everything else from `requirements.txt` is installed as-is.

# %%
# !pip install -q timm==1.0.12 einops huggingface_hub "wandb==0.22.0" diffusers datasets tqdm
print("Done.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.6/51.6 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 43.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 88.1 MB/s eta 0:00:00
# Done.

# %% [markdown]
# ## 3. Configuration (edit this cell)
#
# Every hyperparameter used by `offline_train_ARC.py` and `test_time_train_ARC.py` is defined here.
# Defaults for the **model / offline-training** block mirror `script/offline_train_VARC_ViT.sh`
# (the exact config used to train VARC-ViT-18M in the paper). Defaults for **TTT** mirror
# `script/test_time_training_VARC_ViT_ARC1.sh`. Change anything you like — the launch cells below just
# forward these variables as CLI flags to the untouched scripts.

# %%
import sys, os, subprocess, json, time, glob

os.chdir(REPO_DIR)

# ----------------------------------------------------------------------------------
# Model architecture (must be identical for offline training and TTT — TTT resumes
# from the offline checkpoint, so changing these after offline training breaks loading)
# ----------------------------------------------------------------------------------
ARCHITECTURE   = "vit"     # "vit" or "unet"
IMAGE_SIZE     = 64        # canvas size
PATCH_SIZE     = 2         # ViT patch size
EMBED_DIM      = 512
DEPTH          = 10
NUM_HEADS      = 8
NUM_COLORS     = 12        # 10 ARC colors + background-canvas color + border/shape token

# torch.compile (script/*.sh leave it ON by default, i.e. --no-compile is NOT passed). On a single
# Kaggle GPU it adds extra CUDA-graph memory pools on top of an already-tight budget, and TTT launches
# a fresh model per task so it would recompile from scratch every time. Recommended True on Kaggle;
# set False if you have GPU headroom and want raw throughput on a long offline-training run.
NO_COMPILE = True

# ----------------------------------------------------------------------------------
# Offline training  (script/offline_train_VARC_ViT.sh uses epochs=100 on 8xH200 ~5h12m)
# ----------------------------------------------------------------------------------
OFFLINE_EPOCHS      = 1          # paper default. Try 5-10 for a quick smoke test on Kaggle.
# NOTE: the repo uses batch-size 32 *per GPU* on 80GB H200s. A single Kaggle T4/P100 has ~15GB,
# and at image-size=64/patch-size=2 each sample is a 1025-token sequence, so 32 will OOM on one GPU.
# Start small and raise until you're close to OOM: 8 is safe on a T4, try 12-16 on a P100.
OFFLINE_BATCH_SIZE  = 8
LEARNING_RATE        = 3e-4
WEIGHT_DECAY          = 0
LR_SCHEDULER          = "cosine"
INCLUDE_REARC         = True       # adds RE-ARC synthetic data (400 tasks x up to 1000 examples each)
REARC_LIMIT           = 1         # -1 = all examples/task (paper). e.g. 20-50 for a much faster run.
DATA_ROOT             = "raw_data/ARC-AGI"
TRAIN_SPLIT            = "training"
NUM_WORKERS            = 2
VIS_EVERY              = 50
SAVE_PATH              = "saves/offline_train_ViT/checkpoint_final.pt"
BEST_SAVE_PATH         = "saves/offline_train_ViT/checkpoint_best.pt"

USE_WANDB              = False     # set True + `wandb login` beforehand to enable
WANDB_PROJECT          = "VisionARC"
WANDB_RUN_NAME         = "offline_train_VARC_kaggle"

# ----------------------------------------------------------------------------------
# Test-time training (TTT). script/test_time_training_VARC_ViT_ARC1.sh values below.
# ----------------------------------------------------------------------------------
TTT_EPOCHS         = 100
TTT_BATCH_SIZE     = 8
TTT_NUM_ATTEMPTS   = 10     # random augmented views voted over per test example
TTT_NUM_EACH       = 1      # independent TTT re-runs per task (for ensembling)
TTT_EVAL_SAVE_NAME = "ARC_1_eval_ViT"   # predictions saved under outputs/{name}_attempt_{i}/

# The repo's script runs TTT on ALL 400 ARC-AGI-1 evaluation tasks (in parallel across 8 GPUs).
# On a single Kaggle GPU that is sequential and slow, so by default we only run a handful.
# Bump NUM_TTT_TASKS (up to 400) or replace TTT_TASKS with your own list of task ids to do more.
NUM_TTT_TASKS = 30

ALL_ARC1_EVAL_TASKS = [
    "af24b4cc", "e1d2900e", "903d1b4a", "4e469f39", "b1fc8b8e", "2c737e39", "992798f6", "00576224", "48131b3c", "60a26a3e", 
    "59341089", "31d5ba1a", "e633a9e5", "62ab2642", "73c3b0d8", "c663677b", "c48954c1", "08573cc6", "136b0064", "929ab4e9", 
    "5b526a93", "ef26cbf6", "fafd9572", "67c52801", "ad7e01d0", "506d28a5", "27a77e38", "d492a647", "72a961c9", "fd4b2b02"
]

TTT_TASKS = ALL_ARC1_EVAL_TASKS[:NUM_TTT_TASKS]
print(f"Will run offline training for {OFFLINE_EPOCHS} epochs, then TTT on {len(TTT_TASKS)} task(s):")
print(TTT_TASKS)
# Out:
# Will run offline training for 1 epochs, then TTT on 30 task(s):
# ['af24b4cc', 'e1d2900e', '903d1b4a', '4e469f39', 'b1fc8b8e', '2c737e39', '992798f6', '00576224', '48131b3c', '60a26a3e', '59341089', '31d5ba1a', 'e633a9e5', '62ab2642', '73c3b0d8', 'c663677b', 'c48954c1', '08573cc6', '136b0064', '929ab4e9', '5b526a93', 'ef26cbf6', 'fafd9572', '67c52801', 'ad7e01d0', '506d28a5', '27a77e38', 'd492a647', '72a961c9', 'fd4b2b02']

# %% [markdown]
# ## 4. Helper: run a command and stream its output live

# %%
import sys

def run_streaming(cmd, cwd=REPO_DIR, env=None):
    """Run `cmd` (a list of args) and stream stdout/stderr to the notebook live,
    including the scripts' \r-updating epoch progress bars (train_loss/train_acc/
    eval_acc/eta etc. get printed once per epoch; the % bar updates continuously
    within an epoch)."""
    print("Running:", " ".join(cmd))
    full_env = os.environ.copy()
    full_env["PYTHONUNBUFFERED"] = "1"   # make the child flush immediately, not just on newline
    if env:
        full_env.update(env)

    proc = subprocess.Popen(
        cmd, cwd=cwd, env=full_env,
        stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
        text=True, bufsize=1,
    )
    # Read char-by-char (not line-by-line) so \r progress-bar updates render live
    # instead of being buffered until the next real \n.
    while True:
        ch = proc.stdout.read(1)
        if ch == "" and proc.poll() is not None:
            break
        if ch:
            sys.stdout.write(ch)
            sys.stdout.flush()

    proc.wait()
    if proc.returncode != 0:
        raise RuntimeError(f"Command failed with exit code {proc.returncode}: {' '.join(cmd)}")
    return proc.returncode

# %%
mem_env = {"PYTORCH_CUDA_ALLOC_CONF": "expandable_segments:True", "PYTORCH_ALLOC_CONF": "expandable_segments:True"}

# %%
BEST_SAVE_PATH='/kaggle/input/datasets/rohan547/number2model/checkpoint_best.pt'

# %% [markdown]
# ## 6. Build the augmented per-task TTT dataset
#
# Reproduces `augment_data.py` (called exactly the same way, just imported instead of run as `__main__`):
# for every ARC-AGI-1 evaluation task it writes an `eval_color_permute_ttt_9/<task_id>/` folder containing
# the task's demonstration pairs plus 9 color-permuted copies, which `test_time_train_ARC.py` treats as
# the per-task training set for TTT.

# %%
from utils.data_augmentation import augment_raw_data_split_per_task

t0 = time.time()
augment_raw_data_split_per_task(
    dataset_root="raw_data/ARC-AGI",
    split="evaluation",
    output_subdir="eval_color_permute_ttt_9",
    num_permuate=9,
    only_basic=True,
)
print(f"Augmented TTT dataset built in {(time.time()-t0)/60:.1f} min")
print("Example folder contents:", os.listdir(f"raw_data/ARC-AGI/data/eval_color_permute_ttt_9/{TTT_TASKS[0]}"))
# Out:
# 5 augmenters will be applied
# [augment] Completed split 'evaluation': 20000 augmented tasks prepared in raw_data/ARC-AGI/data/eval_color_permute_ttt_9/ff72ca3e
# Augmented TTT dataset built in 0.6 min
# Example folder contents: ['af24b4cc_flip_0_perm9_augmented.json', 'af24b4cc_rotate_270_perm3_augmented.json', 'af24b4cc_flip_1_perm8_augmented.json', 'af24b4cc_rotate_270_perm2_augmented.json', 'af24b4cc_rotate_270_perm8_augmented.json', 'af24b4cc_rotate_270_perm7_augmented.json', 'af24b4cc_rotate_270_augmented.json', 'af24b4cc_rotate_180_perm4_augmented.json', 'af24b4cc_rotate_180_perm5_augmented.json', 'af24b4cc.json', 'af24b4cc_flip_0_perm5_augmented.json', 'af24b4cc_rotate_90_perm7_augmented.json', 'af24b4cc_rotate_270_perm9_augmented.json', 'af24b4cc_rotate_270_perm5_augmented.json', 'af24b4cc_rotate_90_perm3_augmented.json', 'af24b4cc_flip_0_augmented.json', 'af24b4cc_rotate_180_perm2_augmented.json', 'af24b4cc_flip_1_perm3_augmented.json', 'af24b4cc_rotate_90_perm1_augmented.json', 'af24b4cc_rotate_90_perm5_augmented.json', 'af24b4cc_rotate_180_perm9_augmented.json', 'af24b4cc_flip_1_augmented.json', 'af24b4cc_flip_1_perm2_augmented.json', 'af24b4cc_rotate_180_augmented.json', 'af24b4cc_rotate_180_perm8_augmented.json', 'af24b4cc_flip_0_perm2_augmented.json', 'af24b4cc_rotate_90_perm6_augmented.json', 'af24b4cc_rotate_180_perm7_augmented.json', 'af24b4cc_flip_0_perm1_augmented.json', 'af24b4cc_rotate_270_perm6_augmented.json', 'af24b4cc_rotate_90_augmented.json', 'af24b4cc_flip_1_perm5_augmented.json', 'af24b4cc_flip_1_perm7_augmented.json', 'af24b4cc_flip_1_perm9_augmented.json', 'af24b4cc_flip_0_perm3_augmented.json', 'af24b4cc_rotate_90_perm9_augmented.json', 'af24b4cc_rotate_180_perm3_augmented.json', 'af24b4cc_rotate_180_perm6_augmented.json', 'af24b4cc_flip_0_perm8_augmented.json', 'af24b4cc_rotate_270_perm4_augmented.json', 'af24b4cc_flip_0_perm4_augmented.json', 'af24b4cc_flip_1_perm4_augmented.json', 'af24b4cc_flip_1_perm1_augmented.json', 'af24b4cc_rotate_90_perm2_augmented.json', 'af24b4cc_rotate_90_perm8_augmented.json', 'af24b4cc_flip_0_perm6_augmented.json', 'af24b4cc_rotate_90_perm4_augmented.json', 'af24b4cc_flip_1_perm6_augmented.json', 'af24b4cc_flip_0_perm7_augmented.json', 'af24b4cc_rotate_270_perm1_augmented.json', 'af24b4cc_rotate_180_perm1_augmented.json']

# %%
import os

TTT_SCRIPT = "test_time_train_ARC.py"  # relative to REPO_DIR (cwd should already be REPO_DIR here)
with open(TTT_SCRIPT) as f:
    src = f.read()

# ------------------------------------------------------------------
# 1) init a pixel-accuracy accumulator next to the exact-match ones
# ------------------------------------------------------------------
old_init = """            train_exact = 0
            train_examples = 0"""
new_init = """            train_exact = 0
            train_examples = 0
            train_pixel_correct = 0
            train_pixel_total = 0"""
if new_init in src:
    print("Step 1 already applied, skipping.")
else:
    assert old_init in src, "train_exact/train_examples init block not found"
    src = src.replace(old_init, new_init)

# ------------------------------------------------------------------
# 2) accumulate pixel-level correct/total counts alongside exact-match, per example
# ------------------------------------------------------------------
old_per_example = """                batch_size = inputs.size(0)
                predictions = logits.argmax(dim=1)
                for idx in range(batch_size):
                    target = targets[idx]
                    prediction = predictions[idx]
                    valid = target != IGNORE_INDEX
                    if valid.any():
                        is_exact = bool(torch.equal(prediction[valid], target[valid]))
                    else:
                        is_exact = False
                    train_exact += int(is_exact)
                    train_examples += 1"""
new_per_example = """                batch_size = inputs.size(0)
                predictions = logits.argmax(dim=1)
                for idx in range(batch_size):
                    target = targets[idx]
                    prediction = predictions[idx]
                    valid = target != IGNORE_INDEX
                    if valid.any():
                        is_exact = bool(torch.equal(prediction[valid], target[valid]))
                        train_pixel_correct += int((prediction[valid] == target[valid]).sum().item())
                        train_pixel_total += int(valid.sum().item())
                    else:
                        is_exact = False
                    train_exact += int(is_exact)
                    train_examples += 1"""
if new_per_example in src:
    print("Step 2 already applied, skipping.")
else:
    assert old_per_example in src, "per-example train loop not found"
    src = src.replace(old_per_example, new_per_example)

# ------------------------------------------------------------------
# 3) fold pixel counts into the distributed reduction, compute train_pixel_acc
# ------------------------------------------------------------------
old_reduce = """            train_totals = torch.tensor(
                [running_loss, sample_count, train_exact, train_examples],
                dtype=torch.float64,
                device=device,
            )
            if distributed and dist.is_initialized():
                dist.all_reduce(train_totals, op=dist.ReduceOp.SUM)
            running_loss_total, sample_count_total, train_exact_total, train_examples_total = train_totals.tolist()
            avg_train_loss = running_loss_total / max(sample_count_total, 1)
            train_acc = train_exact_total / max(train_examples_total, 1)"""
new_reduce = """            train_totals = torch.tensor(
                [running_loss, sample_count, train_exact, train_examples, train_pixel_correct, train_pixel_total],
                dtype=torch.float64,
                device=device,
            )
            if distributed and dist.is_initialized():
                dist.all_reduce(train_totals, op=dist.ReduceOp.SUM)
            (running_loss_total, sample_count_total, train_exact_total, train_examples_total,
             train_pixel_correct_total, train_pixel_total_total) = train_totals.tolist()
            avg_train_loss = running_loss_total / max(sample_count_total, 1)
            train_acc = train_exact_total / max(train_examples_total, 1)
            train_pixel_acc = train_pixel_correct_total / max(train_pixel_total_total, 1)"""
if new_reduce in src:
    print("Step 3 already applied, skipping.")
else:
    assert old_reduce in src, "train_totals reduction block not found"
    src = src.replace(old_reduce, new_reduce)

# ------------------------------------------------------------------
# 4) add train_pixel_acc into the per-epoch log line that's already printed live
# ------------------------------------------------------------------
old_log = """            log_parts = [
                f"epoch={epoch}",
                f"train_loss={avg_train_loss:.4f}",
                f"train_acc={train_acc:.4f}",
                f"epoch_time={epoch_duration:.1f}s",
                f"eta_total={_format_eta(total_eta)}",
            ]"""
new_log = """            log_parts = [
                f"epoch={epoch}",
                f"train_loss={avg_train_loss:.4f}",
                f"train_acc={train_acc:.4f}",
                f"train_pixel_acc={train_pixel_acc:.4f}",
                f"epoch_time={epoch_duration:.1f}s",
                f"eta_total={_format_eta(total_eta)}",
            ]"""
if new_log in src:
    print("Step 4 already applied, skipping.")
else:
    assert old_log in src, "log_parts block not found"
    src = src.replace(old_log, new_log)

# ------------------------------------------------------------------
# 5) THIS is the step your earlier patch was missing — write it back to disk
# ------------------------------------------------------------------
with open(TTT_SCRIPT, "w") as f:
    f.write(src)

print(f"✅ Patched {TTT_SCRIPT}: every epoch will now print train_pixel_acc alongside train_loss/train_acc.")
# Out:
# ✅ Patched test_time_train_ARC.py: every epoch will now print train_pixel_acc alongside train_loss/train_acc.

# %% [markdown]
# ## 7. Test-time training (TTT)
#
# For each task in `TTT_TASKS`, calls `test_time_train_ARC.py` exactly as
# `script/test_time_training_VARC_ViT_ARC1.sh` does per task (minus the outer GPU-parallel loop, since
# we have one GPU). Each call: fine-tunes a fresh copy of the offline-trained model on that task's
# augmented demonstrations (`TTT_NUM_EACH` independent times), then predicts the held-out test pair(s)
# with `TTT_NUM_ATTEMPTS` augmented views per attempt and majority-votes the answer. Predictions and a
# per-task Pass@1/Pass@2/Oracle report (via the repo's own `analyze_prediction.py`) are printed live and
# saved under `outputs/{TTT_EVAL_SAVE_NAME}_attempt_{0..TTT_NUM_EACH-1}/`.

# %%
def build_ttt_cmd(task_name):
    return [
        sys.executable, "test_time_train_ARC.py",
        "--epochs", str(TTT_EPOCHS),
        "--depth", str(DEPTH),
        "--batch-size", str(TTT_BATCH_SIZE),
        "--image-size", str(IMAGE_SIZE),
        "--patch-size", str(PATCH_SIZE),
        "--learning-rate", str(LEARNING_RATE),
        "--weight-decay", str(WEIGHT_DECAY),
        "--embed-dim", str(EMBED_DIM),
        "--num-heads", str(NUM_HEADS),
        "--num-colors", str(NUM_COLORS),
        "--resume-checkpoint", BEST_SAVE_PATH,
        "--resume-skip-task-token",
        "--lr-scheduler", LR_SCHEDULER,
        "--train-split", f"eval_color_permute_ttt_9/{task_name}",
        "--eval-split", f"eval_color_permute_ttt_9/{task_name}",
        "--data-root", DATA_ROOT,
        "--architecture", ARCHITECTURE,
        "--eval-save-name", TTT_EVAL_SAVE_NAME,
        "--num-attempts", str(TTT_NUM_ATTEMPTS),
        "--ttt-num-each", str(TTT_NUM_EACH),
    ] + (["--no-compile"] if NO_COMPILE else [])

import os, json, time, sys
import numpy as np
from utils.eval_utils import get_majority_vote

def compute_task_pixel_stats(task_name, save_name, num_each, data_root):
    """Merge predictions across TTT attempts for one task, compute pixel/exact
    stats using the top majority-voted prediction (same guess used for pass@1)."""
    task_type = data_root.split("/")[-1]
    merged = None
    for i in range(num_each):
        fp = f"outputs/{save_name}_attempt_{i}/{task_name}_predictions.json"
        if not os.path.exists(fp):
            continue
        with open(fp) as f:
            d = json.load(f)
        if merged is None:
            merged = {k: list(v) for k, v in d.items()}
        else:
            for k, v in d.items():
                merged.setdefault(k, [])
                merged[k] += v
    if merged is None:
        print(f"  [warn] no predictions found for {task_name}")
        return None

    gt_path = f"raw_data/{task_type}/data/evaluation/{task_name}.json"
    with open(gt_path) as f:
        gt_data = json.load(f)

    correct_px = total_px = exact = pairs = 0
    rows = []
    for idx_str, preds in merged.items():
        pair_idx = int(idx_str)
        gt_grid = np.array(gt_data["test"][pair_idx]["output"])
        mv = get_majority_vote(preds)
        pred_grid = np.array(mv[0]["prediction"]) if mv else None

        if pred_grid is not None and pred_grid.shape == gt_grid.shape:
            correct = int(np.sum(pred_grid == gt_grid))
        elif pred_grid is not None:
            min_h = min(gt_grid.shape[0], pred_grid.shape[0])
            min_w = min(gt_grid.shape[1], pred_grid.shape[1])
            correct = int(np.sum(gt_grid[:min_h, :min_w] == pred_grid[:min_h, :min_w])) if min_h > 0 and min_w > 0 else 0
        else:
            correct = 0

        total = gt_grid.size
        is_exact = pred_grid is not None and pred_grid.shape == gt_grid.shape and correct == total
        pix_acc = correct / total * 100 if total else 0.0

        correct_px += correct; total_px += total; exact += int(is_exact); pairs += 1
        rows.append((pair_idx, pix_acc, is_exact))

    task_pixel_acc = correct_px / max(total_px, 1) * 100
    task_exact_acc = exact / max(pairs, 1) * 100
    print(f"  -> {task_name}: pixel_acc={task_pixel_acc:.2f}%  exact_match={task_exact_acc:.2f}%  ({pairs} test pair(s))")
    for pair_idx, pix_acc, is_exact in rows:
        print(f"       pair {pair_idx}: pixel_acc={pix_acc:6.2f}%  {'✅' if is_exact else '❌'}")

    return dict(correct_px=correct_px, total_px=total_px, exact=exact, pairs=pairs)

# --- Run TTT task-by-task, printing pixel accuracy right after each ---
t0 = time.time()
task_pixel_stats = {}
for i, task_name in enumerate(TTT_TASKS, 1):
    print(f"\n===== [{i}/{len(TTT_TASKS)}] TTT on task {task_name} =====")
    run_streaming(build_ttt_cmd(task_name), env=mem_env)
    stats = compute_task_pixel_stats(task_name, TTT_EVAL_SAVE_NAME, TTT_NUM_EACH, DATA_ROOT)
    if stats is not None:
        task_pixel_stats[task_name] = stats
print(f"\nTTT finished for {len(TTT_TASKS)} task(s) in {(time.time()-t0)/60:.1f} min")
# Out:
# ===== [1/30] TTT on task af24b4cc =====
# Running: /usr/bin/python3 test_time_train_ARC.py --epochs 100 --depth 10 --batch-size 8 --image-size 64 --patch-size 2 --learning-rate 0.0003 --weight-decay 0 --embed-dim 512 --num-heads 8 --num-colors 12 --resume-checkpoint /kaggle/input/datasets/rohan547/number2model/checkpoint_best.pt --resume-skip-task-token --lr-scheduler cosine --train-split eval_color_permute_ttt_9/af24b4cc --eval-split eval_color_permute_ttt_9/af24b4cc --data-root raw_data/ARC-AGI --architecture vit --eval-save-name ARC_1_eval_ViT --num-attempts 10 --ttt-num-each 1 --no-compile
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Start loading data...
# Finish loading!!
# Start loading data...
# Finish loading!!
# Total training examples: 153
# Resuming from checkpoint: /kaggle/input/datasets/rohan547/number2model/checkpoint_best.pt
# Patch size: 2, sequence length: 1024
# Skipped loading parameters: ['task_token_embed.weight']
# Starting test-time training attempt 1/1...
# Using automatic mixed precision (AMP) training
#
# Epoch 0 [------------------------------]   0.5% ETA 00h23m59s
# Epoch 0 [------------------------------]   1.0% ETA 00h20m10s
# epoch=0 | train_loss=3.0090 | train_acc=0.0000 | train_pixel_acc=0.4602 | epoch_time=12.2s | eta_total=00h20m10s | lr=0.000000
#
# Epoch 1 [------------------------------]   1.5% ETA 00h19m22s
# Epoch 1 [------------------------------]   2.0% ETA 00h18m32s
# epoch=1 | train_loss=1.8909 | train_acc=0.0000 | train_pixel_acc=0.5806 | epoch_time=10.5s | eta_total=00h18m33s | lr=0.000030
#
# Epoch 2 [------------------------------]   2.5% ETA 00h18m20s
# Epoch 2 [------------------------------]   3.0% ETA 00h17m55s
# epoch=2 | train_loss=1.1426 | train_acc=0.0000 | train_pixel_acc=0.6409 | epoch_time=10.6s | eta_total=00h17m55s | lr=0.000060
#
# Epoch 3 [#-----------------------------]   3.5% ETA 00h17m50s
# Epoch 3 [#-----------------------------]   4.0% ETA 00h17m33s
# epoch=3 | train_loss=0.8255 | train_acc=0.0000 | train_pixel_acc=0.7007 | epoch_time=10.6s | eta_total=00h17m33s | lr=0.000090
#
# Epoch 4 [#-----------------------------]   4.5% ETA 00h17m29s
# Epoch 4 [#-----------------------------]   5.0% ETA 00h17m17s
# epoch=4 | train_loss=0.5797 | train_acc=0.0000 | train_pixel_acc=0.7913 | epoch_time=10.7s | eta_total=00h17m17s | lr=0.000120
#
# Epoch 5 [#-----------------------------]   5.5% ETA 00h17m15s
# Epoch 5 [#-----------------------------]   6.0% ETA 00h17m05s
# epoch=5 | train_loss=0.4993 | train_acc=0.0000 | train_pixel_acc=0.8194 | epoch_time=10.8s | eta_total=00h17m05s | lr=0.000150
#
# Epoch 6 [#-----------------------------]   6.5% ETA 00h17m03s
# Epoch 6 [##----------------------------]   7.0% ETA 00h16m55s
# epoch=6 | train_loss=0.3942 | train_acc=0.0000 | train_pixel_acc=0.8592 | epoch_time=11.0s | eta_total=00h16m55s | lr=0.000180
#
# Epoch 7 [##----------------------------]   7.5% ETA 00h16m53s
# Epoch 7 [##----------------------------]   8.0% ETA 00h16m45s
# epoch=7 | train_loss=0.3728 | train_acc=0.0000 | train_pixel_acc=0.8669 | epoch_time=11.1s | eta_total=00h16m45s | lr=0.000210
#
# Epoch 8 [##----------------------------]   8.5% ETA 00h16m44s
# Epoch 8 [##----------------------------]   9.0% ETA 00h16m36s
# epoch=8 | train_loss=0.3462 | train_acc=0.0000 | train_pixel_acc=0.8785 | epoch_time=11.1s | eta_total=00h16m36s | lr=0.000240
#
# Epoch 9 [##----------------------------]   9.5% ETA 00h16m34s
# Epoch 9 [###---------------------------]  10.0% ETA 00h16m26s
# epoch=9 | train_loss=0.2995 | train_acc=0.0000 | train_pixel_acc=0.8967 | epoch_time=11.0s | eta_total=00h16m26s | lr=0.000270
#
# Epoch 10 [###---------------------------]  10.5% ETA 00h16m23s
# Epoch 10 [###---------------------------]  11.0% ETA 00h16m15s
# epoch=10 | train_loss=0.2616 | train_acc=0.0000 | train_pixel_acc=0.9066 | epoch_time=11.0s | eta_total=00h16m15s | lr=0.000300
#
# Epoch 11 [###---------------------------]  11.5% ETA 00h16m11s
# Epoch 11 [###---------------------------]  12.0% ETA 00h16m04s
# epoch=11 | train_loss=0.2381 | train_acc=0.0000 | train_pixel_acc=0.9146 | epoch_time=10.9s | eta_total=00h16m04s | lr=0.000300
#
# Epoch 12 [###---------------------------]  12.5% ETA 00h16m00s
# Epoch 12 [###---------------------------]  13.0% ETA 00h15m52s
# epoch=12 | train_loss=0.2382 | train_acc=0.0000 | train_pixel_acc=0.9167 | epoch_time=10.9s | eta_total=00h15m52s | lr=0.000300
#
# Epoch 13 [####--------------------------]  13.5% ETA 00h15m48s
# Epoch 13 [####--------------------------]  14.0% ETA 00h15m41s
# epoch=13 | train_loss=0.2287 | train_acc=0.0000 | train_pixel_acc=0.9210 | epoch_time=10.9s | eta_total=00h15m41s | lr=0.000299
#
# Epoch 14 [####--------------------------]  14.5% ETA 00h15m37s
# Epoch 14 [####--------------------------]  15.0% ETA 00h15m30s
# epoch=14 | train_loss=0.2052 | train_acc=0.0000 | train_pixel_acc=0.9329 | epoch_time=11.0s | eta_total=00h15m30s | lr=0.000299
#
# Epoch 15 [####--------------------------]  15.5% ETA 00h15m26s
# Epoch 15 [####--------------------------]  16.0% ETA 00h15m20s
# epoch=15 | train_loss=0.1788 | train_acc=0.0000 | train_pixel_acc=0.9412 | epoch_time=11.0s | eta_total=00h15m20s | lr=0.000298
#
# Epoch 16 [####--------------------------]  16.5% ETA 00h15m16s
# Epoch 16 [#####-------------------------]  17.0% ETA 00h15m09s
# epoch=16 | train_loss=0.1654 | train_acc=0.0000 | train_pixel_acc=0.9447 | epoch_time=11.0s | eta_total=00h15m09s | lr=0.000297
#
# Epoch 17 [#####-------------------------]  17.5% ETA 00h15m05s
# Epoch 17 [#####-------------------------]  18.0% ETA 00h14m58s
# epoch=17 | train_loss=0.1707 | train_acc=0.0000 | train_pixel_acc=0.9419 | epoch_time=11.0s | eta_total=00h14m58s | lr=0.000296
#
# Epoch 18 [#####-------------------------]  18.5% ETA 00h14m54s
# Epoch 18 [#####-------------------------]  19.0% ETA 00h14m47s
# epoch=18 | train_loss=0.1323 | train_acc=0.0196 | train_pixel_acc=0.9558 | epoch_time=11.0s | eta_total=00h14m47s | lr=0.000294
#
# Epoch 19 [#####-------------------------]  19.5% ETA 00h14m43s
# Epoch 19 [######------------------------]  20.0% ETA 00h14m36s
# epoch=19 | train_loss=0.1254 | train_acc=0.0131 | train_pixel_acc=0.9550 | epoch_time=11.0s | eta_total=00h14m36s | lr=0.000293
#
# Epoch 20 [######------------------------]  20.5% ETA 00h14m32s
# Epoch 20 [######------------------------]  21.0% ETA 00h14m25s
# epoch=20 | train_loss=0.1217 | train_acc=0.0196 | train_pixel_acc=0.9587 | epoch_time=11.0s | eta_total=00h14m25s | lr=0.000291
#
# Epoch 21 [######------------------------]  21.5% ETA 00h14m21s
# Epoch 21 [######------------------------]  22.0% ETA 00h14m14s
# epoch=21 | train_loss=0.1285 | train_acc=0.0196 | train_pixel_acc=0.9584 | epoch_time=11.0s | eta_total=00h14m14s | lr=0.000289
#
# Epoch 22 [######------------------------]  22.5% ETA 00h14m10s
# Epoch 22 [######------------------------]  23.0% ETA 00h14m03s
# epoch=22 | train_loss=0.1085 | train_acc=0.0327 | train_pixel_acc=0.9628 | epoch_time=11.0s | eta_total=00h14m03s | lr=0.000287
#
# Epoch 23 [#######-----------------------]  23.5% ETA 00h13m59s
# Epoch 23 [#######-----------------------]  24.0% ETA 00h13m53s
# epoch=23 | train_loss=0.0954 | train_acc=0.0065 | train_pixel_acc=0.9665 | epoch_time=11.0s | eta_total=00h13m53s | lr=0.000285
#
# Epoch 24 [#######-----------------------]  24.5% ETA 00h13m48s
# Epoch 24 [#######-----------------------]  25.0% ETA 00h13m42s
# epoch=24 | train_loss=0.0851 | train_acc=0.0523 | train_pixel_acc=0.9706 | epoch_time=10.9s | eta_total=00h13m42s | lr=0.000282
#
# Epoch 25 [#######-----------------------]  25.5% ETA 00h13m37s
# Epoch 25 [#######-----------------------]  26.0% ETA 00h13m31s
# epoch=25 | train_loss=0.1030 | train_acc=0.0327 | train_pixel_acc=0.9674 | epoch_time=10.9s | eta_total=00h13m31s | lr=0.000280
#
# Epoch 26 [#######-----------------------]  26.5% ETA 00h13m26s
# Epoch 26 [########----------------------]  27.0% ETA 00h13m19s
# epoch=26 | train_loss=0.0878 | train_acc=0.0261 | train_pixel_acc=0.9707 | epoch_time=10.9s | eta_total=00h13m19s | lr=0.000277
#
# Epoch 27 [########----------------------]  27.5% ETA 00h13m15s
# Epoch 27 [########----------------------]  28.0% ETA 00h13m08s
# epoch=27 | train_loss=0.0720 | train_acc=0.0654 | train_pixel_acc=0.9755 | epoch_time=10.9s | eta_total=00h13m08s | lr=0.000274
#
# Epoch 28 [########----------------------]  28.5% ETA 00h13m04s
# Epoch 28 [########----------------------]  29.0% ETA 00h12m58s
# epoch=28 | train_loss=0.0638 | train_acc=0.0392 | train_pixel_acc=0.9797 | epoch_time=11.0s | eta_total=00h12m58s | lr=0.000271
#
# Epoch 29 [########----------------------]  29.5% ETA 00h12m53s
# Epoch 29 [#########---------------------]  30.0% ETA 00h12m47s
# epoch=29 | train_loss=0.0553 | train_acc=0.1046 | train_pixel_acc=0.9822 | epoch_time=11.0s | eta_total=00h12m47s | lr=0.000268
#
# Epoch 30 [#########---------------------]  30.5% ETA 00h12m42s
# Epoch 30 [#########---------------------]  31.0% ETA 00h12m36s
# epoch=30 | train_loss=0.0558 | train_acc=0.0980 | train_pixel_acc=0.9838 | epoch_time=11.0s | eta_total=00h12m36s | lr=0.000265
#
# Epoch 31 [#########---------------------]  31.5% ETA 00h12m31s
# Epoch 31 [#########---------------------]  32.0% ETA 00h12m25s
# epoch=31 | train_loss=0.0444 | train_acc=0.1176 | train_pixel_acc=0.9873 | epoch_time=11.0s | eta_total=00h12m25s | lr=0.000261
#
# Epoch 32 [#########---------------------]  32.5% ETA 00h12m20s
# Epoch 32 [#########---------------------]  33.0% ETA 00h12m14s
# epoch=32 | train_loss=0.0300 | train_acc=0.2092 | train_pixel_acc=0.9910 | epoch_time=11.0s | eta_total=00h12m14s | lr=0.000258
#
# Epoch 33 [##########--------------------]  33.5% ETA 00h12m09s
# Epoch 33 [##########--------------------]  34.0% ETA 00h12m03s
# epoch=33 | train_loss=0.0368 | train_acc=0.1373 | train_pixel_acc=0.9883 | epoch_time=10.9s | eta_total=00h12m03s | lr=0.000254
#
# Epoch 34 [##########--------------------]  34.5% ETA 00h11m58s
# Epoch 34 [##########--------------------]  35.0% ETA 00h11m52s
# epoch=34 | train_loss=0.0294 | train_acc=0.2157 | train_pixel_acc=0.9923 | epoch_time=11.0s | eta_total=00h11m52s | lr=0.000250
#
# Epoch 35 [##########--------------------]  35.5% ETA 00h11m47s
# Epoch 35 [##########--------------------]  36.0% ETA 00h11m41s
# epoch=35 | train_loss=0.0255 | train_acc=0.2614 | train_pixel_acc=0.9937 | epoch_time=11.0s | eta_total=00h11m41s | lr=0.000246
#
# Epoch 36 [##########--------------------]  36.5% ETA 00h11m36s
# Epoch 36 [###########-------------------]  37.0% ETA 00h11m30s
# epoch=36 | train_loss=0.0289 | train_acc=0.2353 | train_pixel_acc=0.9923 | epoch_time=11.0s | eta_total=00h11m30s | lr=0.000242
#
# Epoch 37 [###########-------------------]  37.5% ETA 00h11m25s
# Epoch 37 [###########-------------------]  38.0% ETA 00h11m19s
# epoch=37 | train_loss=0.0278 | train_acc=0.2680 | train_pixel_acc=0.9925 | epoch_time=11.0s | eta_total=00h11m19s | lr=0.000238
#
# Epoch 38 [###########-------------------]  38.5% ETA 00h11m14s
# Epoch 38 [###########-------------------]  39.0% ETA 00h11m08s
# epoch=38 | train_loss=0.0208 | train_acc=0.3595 | train_pixel_acc=0.9946 | epoch_time=11.0s | eta_total=00h11m08s | lr=0.000234
#
# Epoch 39 [###########-------------------]  39.5% ETA 00h11m03s
# Epoch 39 [############------------------]  40.0% ETA 00h10m57s
# epoch=39 | train_loss=0.0300 | train_acc=0.2353 | train_pixel_acc=0.9917 | epoch_time=10.9s | eta_total=00h10m57s | lr=0.000229
#
# Epoch 40 [############------------------]  40.5% ETA 00h10m52s
# Epoch 40 [############------------------]  41.0% ETA 00h10m46s
# epoch=40 | train_loss=0.0257 | train_acc=0.2484 | train_pixel_acc=0.9926 | epoch_time=11.0s | eta_total=00h10m46s | lr=0.000225
#
# Epoch 41 [############------------------]  41.5% ETA 00h10m41s
# Epoch 41 [############------------------]  42.0% ETA 00h10m35s
# epoch=41 | train_loss=0.0177 | train_acc=0.3529 | train_pixel_acc=0.9954 | epoch_time=11.0s | eta_total=00h10m35s | lr=0.000220
#
# Epoch 42 [############------------------]  42.5% ETA 00h10m30s
# Epoch 42 [############------------------]  43.0% ETA 00h10m24s
# epoch=42 | train_loss=0.0161 | train_acc=0.3922 | train_pixel_acc=0.9956 | epoch_time=11.0s | eta_total=00h10m24s | lr=0.000216
#
# Epoch 43 [#############-----------------]  43.5% ETA 00h10m19s
# Epoch 43 [#############-----------------]  44.0% ETA 00h10m13s
# epoch=43 | train_loss=0.0157 | train_acc=0.4510 | train_pixel_acc=0.9956 | epoch_time=11.0s | eta_total=00h10m13s | lr=0.000211
#
# Epoch 44 [#############-----------------]  44.5% ETA 00h10m08s
# Epoch 44 [#############-----------------]  45.0% ETA 00h10m02s
# epoch=44 | train_loss=0.0132 | train_acc=0.4248 | train_pixel_acc=0.9967 | epoch_time=11.0s | eta_total=00h10m02s | lr=0.000206
#
# Epoch 45 [#############-----------------]  45.5% ETA 00h09m57s
# Epoch 45 [#############-----------------]  46.0% ETA 00h09m51s
# epoch=45 | train_loss=0.0122 | train_acc=0.4902 | train_pixel_acc=0.9969 | epoch_time=11.0s | eta_total=00h09m51s | lr=0.000201
#
# Epoch 46 [#############-----------------]  46.5% ETA 00h09m46s
# Epoch 46 [##############----------------]  47.0% ETA 00h09m40s
# epoch=46 | train_loss=0.0109 | train_acc=0.5817 | train_pixel_acc=0.9975 | epoch_time=11.0s | eta_total=00h09m40s | lr=0.000196
#
# Epoch 47 [##############----------------]  47.5% ETA 00h09m35s
# Epoch 47 [##############----------------]  48.0% ETA 00h09m30s
# epoch=47 | train_loss=0.0105 | train_acc=0.5817 | train_pixel_acc=0.9974 | epoch_time=11.0s | eta_total=00h09m30s | lr=0.000191
#
# Epoch 48 [##############----------------]  48.5% ETA 00h09m24s
# Epoch 48 [##############----------------]  49.0% ETA 00h09m19s
# epoch=48 | train_loss=0.0094 | train_acc=0.6275 | train_pixel_acc=0.9978 | epoch_time=11.0s | eta_total=00h09m19s | lr=0.000186
#
# Epoch 49 [##############----------------]  49.5% ETA 00h09m13s
# Epoch 49 [###############---------------]  50.0% ETA 00h09m08s
# epoch=49 | train_loss=0.0087 | train_acc=0.6013 | train_pixel_acc=0.9981 | epoch_time=11.0s | eta_total=00h09m08s | lr=0.000181
#
# Epoch 50 [###############---------------]  50.5% ETA 00h09m02s
# Epoch 50 [###############---------------]  51.0% ETA 00h08m57s
# epoch=50 | train_loss=0.0093 | train_acc=0.5817 | train_pixel_acc=0.9980 | epoch_time=11.0s | eta_total=00h08m57s | lr=0.000176
#
# Epoch 51 [###############---------------]  51.5% ETA 00h08m51s
# Epoch 51 [###############---------------]  52.0% ETA 00h08m46s
# epoch=51 | train_loss=0.0098 | train_acc=0.5556 | train_pixel_acc=0.9976 | epoch_time=11.0s | eta_total=00h08m46s | lr=0.000171
#
# Epoch 52 [###############---------------]  52.5% ETA 00h08m40s
# Epoch 52 [###############---------------]  53.0% ETA 00h08m35s
# epoch=52 | train_loss=0.0089 | train_acc=0.5817 | train_pixel_acc=0.9978 | epoch_time=11.0s | eta_total=00h08m35s | lr=0.000166
#
# Epoch 53 [################--------------]  53.5% ETA 00h08m30s
# Epoch 53 [################--------------]  54.0% ETA 00h08m24s
# epoch=53 | train_loss=0.0078 | train_acc=0.6863 | train_pixel_acc=0.9984 | epoch_time=11.0s | eta_total=00h08m24s | lr=0.000160
#
# Epoch 54 [################--------------]  54.5% ETA 00h08m19s
# Epoch 54 [################--------------]  55.0% ETA 00h08m13s
# epoch=54 | train_loss=0.0068 | train_acc=0.6863 | train_pixel_acc=0.9985 | epoch_time=11.0s | eta_total=00h08m13s | lr=0.000155
#
# Epoch 55 [################--------------]  55.5% ETA 00h08m08s
# Epoch 55 [################--------------]  56.0% ETA 00h08m02s
# epoch=55 | train_loss=0.0071 | train_acc=0.7320 | train_pixel_acc=0.9989 | epoch_time=11.0s | eta_total=00h08m02s | lr=0.000150
#
# Epoch 56 [################--------------]  56.5% ETA 00h07m57s
# Epoch 56 [#################-------------]  57.0% ETA 00h07m51s
# epoch=56 | train_loss=0.0084 | train_acc=0.6536 | train_pixel_acc=0.9980 | epoch_time=10.9s | eta_total=00h07m51s | lr=0.000145
#
# Epoch 57 [#################-------------]  57.5% ETA 00h07m46s
# Epoch 57 [#################-------------]  58.0% ETA 00h07m40s
# epoch=57 | train_loss=0.0076 | train_acc=0.6993 | train_pixel_acc=0.9984 | epoch_time=10.9s | eta_total=00h07m40s | lr=0.000140
#
# Epoch 58 [#################-------------]  58.5% ETA 00h07m35s
# Epoch 58 [#################-------------]  59.0% ETA 00h07m29s
# epoch=58 | train_loss=0.0096 | train_acc=0.6601 | train_pixel_acc=0.9979 | epoch_time=10.9s | eta_total=00h07m29s | lr=0.000134
#
# Epoch 59 [#################-------------]  59.5% ETA 00h07m24s
# Epoch 59 [##################------------]  60.0% ETA 00h07m18s
# epoch=59 | train_loss=0.0046 | train_acc=0.7190 | train_pixel_acc=0.9990 | epoch_time=11.0s | eta_total=00h07m18s | lr=0.000129
#
# Epoch 60 [##################------------]  60.5% ETA 00h07m13s
# Epoch 60 [##################------------]  61.0% ETA 00h07m07s
# epoch=60 | train_loss=0.0044 | train_acc=0.7647 | train_pixel_acc=0.9991 | epoch_time=11.0s | eta_total=00h07m07s | lr=0.000124
#
# Epoch 61 [##################------------]  61.5% ETA 00h07m02s
# Epoch 61 [##################------------]  62.0% ETA 00h06m56s
# epoch=61 | train_loss=0.0043 | train_acc=0.7974 | train_pixel_acc=0.9993 | epoch_time=11.0s | eta_total=00h06m56s | lr=0.000119
#
# Epoch 62 [##################------------]  62.5% ETA 00h06m51s
# Epoch 62 [##################------------]  63.0% ETA 00h06m45s
# epoch=62 | train_loss=0.0045 | train_acc=0.7843 | train_pixel_acc=0.9990 | epoch_time=10.9s | eta_total=00h06m45s | lr=0.000114
#
# Epoch 63 [###################-----------]  63.5% ETA 00h06m40s
# Epoch 63 [###################-----------]  64.0% ETA 00h06m34s
# epoch=63 | train_loss=0.0043 | train_acc=0.8366 | train_pixel_acc=0.9993 | epoch_time=11.0s | eta_total=00h06m34s | lr=0.000109
#
# Epoch 64 [###################-----------]  64.5% ETA 00h06m29s
# Epoch 64 [###################-----------]  65.0% ETA 00h06m23s
# epoch=64 | train_loss=0.0046 | train_acc=0.8105 | train_pixel_acc=0.9991 | epoch_time=10.9s | eta_total=00h06m23s | lr=0.000104
#
# Epoch 65 [###################-----------]  65.5% ETA 00h06m18s
# Epoch 65 [###################-----------]  66.0% ETA 00h06m12s
# epoch=65 | train_loss=0.0048 | train_acc=0.7451 | train_pixel_acc=0.9990 | epoch_time=10.9s | eta_total=00h06m12s | lr=0.000099
#
# Epoch 66 [###################-----------]  66.5% ETA 00h06m07s
# Epoch 66 [####################----------]  67.0% ETA 00h06m01s
# epoch=66 | train_loss=0.0044 | train_acc=0.8170 | train_pixel_acc=0.9991 | epoch_time=10.9s | eta_total=00h06m01s | lr=0.000094
#
# Epoch 67 [####################----------]  67.5% ETA 00h05m56s
# Epoch 67 [####################----------]  68.0% ETA 00h05m50s
# epoch=67 | train_loss=0.0048 | train_acc=0.7582 | train_pixel_acc=0.9989 | epoch_time=11.0s | eta_total=00h05m50s | lr=0.000089
#
# Epoch 68 [####################----------]  68.5% ETA 00h05m45s
# Epoch 68 [####################----------]  69.0% ETA 00h05m39s
# epoch=68 | train_loss=0.0040 | train_acc=0.8431 | train_pixel_acc=0.9993 | epoch_time=10.9s | eta_total=00h05m39s | lr=0.000084
#
# Epoch 69 [####################----------]  69.5% ETA 00h05m34s
# Epoch 69 [#####################---------]  70.0% ETA 00h05m28s
# epoch=69 | train_loss=0.0033 | train_acc=0.8105 | train_pixel_acc=0.9993 | epoch_time=11.0s | eta_total=00h05m28s | lr=0.000080
#
# Epoch 70 [#####################---------]  70.5% ETA 00h05m23s
# Epoch 70 [#####################---------]  71.0% ETA 00h05m17s
# epoch=70 | train_loss=0.0049 | train_acc=0.8235 | train_pixel_acc=0.9993 | epoch_time=11.0s | eta_total=00h05m17s | lr=0.000075
#
# Epoch 71 [#####################---------]  71.5% ETA 00h05m12s
# Epoch 71 [#####################---------]  72.0% ETA 00h05m06s
# epoch=71 | train_loss=0.0032 | train_acc=0.7582 | train_pixel_acc=0.9991 | epoch_time=11.0s | eta_total=00h05m06s | lr=0.000071
#
# Epoch 72 [#####################---------]  72.5% ETA 00h05m01s
# Epoch 72 [#####################---------]  73.0% ETA 00h04m55s
# epoch=72 | train_loss=0.0037 | train_acc=0.8301 | train_pixel_acc=0.9993 | epoch_time=11.0s | eta_total=00h04m55s | lr=0.000066
#
# Epoch 73 [######################--------]  73.5% ETA 00h04m50s
# Epoch 73 [######################--------]  74.0% ETA 00h04m44s
# epoch=73 | train_loss=0.0034 | train_acc=0.8301 | train_pixel_acc=0.9994 | epoch_time=11.0s | eta_total=00h04m44s | lr=0.000062
#
# Epoch 74 [######################--------]  74.5% ETA 00h04m39s
# Epoch 74 [######################--------]  75.0% ETA 00h04m34s
# epoch=74 | train_loss=0.0032 | train_acc=0.8497 | train_pixel_acc=0.9994 | epoch_time=11.0s | eta_total=00h04m34s | lr=0.000058
#
# Epoch 75 [######################--------]  75.5% ETA 00h04m28s
# Epoch 75 [######################--------]  76.0% ETA 00h04m23s
# epoch=75 | train_loss=0.0035 | train_acc=0.8105 | train_pixel_acc=0.9993 | epoch_time=11.0s | eta_total=00h04m23s | lr=0.000054
#
# Epoch 76 [######################--------]  76.5% ETA 00h04m17s
# Epoch 76 [#######################-------]  77.0% ETA 00h04m12s
# epoch=76 | train_loss=0.0032 | train_acc=0.8497 | train_pixel_acc=0.9994 | epoch_time=10.9s | eta_total=00h04m12s | lr=0.000050
#
# Epoch 77 [#######################-------]  77.5% ETA 00h04m06s
# Epoch 77 [#######################-------]  78.0% ETA 00h04m01s
# epoch=77 | train_loss=0.0035 | train_acc=0.8693 | train_pixel_acc=0.9994 | epoch_time=10.9s | eta_total=00h04m01s | lr=0.000046
#
# Epoch 78 [#######################-------]  78.5% ETA 00h03m55s
# Epoch 78 [#######################-------]  79.0% ETA 00h03m50s
# epoch=78 | train_loss=0.0041 | train_acc=0.7843 | train_pixel_acc=0.9992 | epoch_time=10.9s | eta_total=00h03m50s | lr=0.000042
#
# Epoch 79 [#######################-------]  79.5% ETA 00h03m44s
# Epoch 79 [########################------]  80.0% ETA 00h03m39s
# epoch=79 | train_loss=0.0038 | train_acc=0.8105 | train_pixel_acc=0.9992 | epoch_time=10.9s | eta_total=00h03m39s | lr=0.000039
#
# Epoch 80 [########################------]  80.5% ETA 00h03m33s
# Epoch 80 [########################------]  81.0% ETA 00h03m28s
# epoch=80 | train_loss=0.0026 | train_acc=0.8693 | train_pixel_acc=0.9996 | epoch_time=11.0s | eta_total=00h03m28s | lr=0.000035
#
# Epoch 81 [########################------]  81.5% ETA 00h03m22s
# Epoch 81 [########################------]  82.0% ETA 00h03m17s
# epoch=81 | train_loss=0.0032 | train_acc=0.8954 | train_pixel_acc=0.9996 | epoch_time=11.0s | eta_total=00h03m17s | lr=0.000032
#
# Epoch 82 [########################------]  82.5% ETA 00h03m11s
# Epoch 82 [########################------]  83.0% ETA 00h03m06s
# epoch=82 | train_loss=0.0045 | train_acc=0.8039 | train_pixel_acc=0.9992 | epoch_time=10.9s | eta_total=00h03m06s | lr=0.000029
#
# Epoch 83 [#########################-----]  83.5% ETA 00h03m00s
# Epoch 83 [#########################-----]  84.0% ETA 00h02m55s
# epoch=83 | train_loss=0.0038 | train_acc=0.8301 | train_pixel_acc=0.9993 | epoch_time=10.9s | eta_total=00h02m55s | lr=0.000026
#
# Epoch 84 [#########################-----]  84.5% ETA 00h02m49s
# Epoch 84 [#########################-----]  85.0% ETA 00h02m44s
# epoch=84 | train_loss=0.0022 | train_acc=0.8758 | train_pixel_acc=0.9996 | epoch_time=11.0s | eta_total=00h02m44s | lr=0.000023
#
# Epoch 85 [#########################-----]  85.5% ETA 00h02m38s
# Epoch 85 [#########################-----]  86.0% ETA 00h02m33s
# epoch=85 | train_loss=0.0034 | train_acc=0.8301 | train_pixel_acc=0.9993 | epoch_time=10.9s | eta_total=00h02m33s | lr=0.000020
#
# Epoch 86 [#########################-----]  86.5% ETA 00h02m27s
# Epoch 86 [##########################----]  87.0% ETA 00h02m22s
# epoch=86 | train_loss=0.0031 | train_acc=0.8758 | train_pixel_acc=0.9995 | epoch_time=10.9s | eta_total=00h02m22s | lr=0.000018
#
# Epoch 87 [##########################----]  87.5% ETA 00h02m17s
# Epoch 87 [##########################----]  88.0% ETA 00h02m11s
# epoch=87 | train_loss=0.0029 | train_acc=0.8954 | train_pixel_acc=0.9996 | epoch_time=10.9s | eta_total=00h02m11s | lr=0.000015
#
# Epoch 88 [##########################----]  88.5% ETA 00h02m06s
# Epoch 88 [##########################----]  89.0% ETA 00h02m00s
# epoch=88 | train_loss=0.0023 | train_acc=0.8889 | train_pixel_acc=0.9996 | epoch_time=11.0s | eta_total=00h02m00s | lr=0.000013
#
# Epoch 89 [##########################----]  89.5% ETA 00h01m55s
# Epoch 89 [###########################---]  90.0% ETA 00h01m49s
# epoch=89 | train_loss=0.0028 | train_acc=0.8954 | train_pixel_acc=0.9996 | epoch_time=11.0s | eta_total=00h01m49s | lr=0.000011
#
# Epoch 90 [###########################---]  90.5% ETA 00h01m44s
# Epoch 90 [###########################---]  91.0% ETA 00h01m38s
# epoch=90 | train_loss=0.0033 | train_acc=0.8497 | train_pixel_acc=0.9994 | epoch_time=10.9s | eta_total=00h01m38s | lr=0.000009
#
# Epoch 91 [###########################---]  91.5% ETA 00h01m33s
# Epoch 91 [###########################---]  92.0% ETA 00h01m27s
# epoch=91 | train_loss=0.0023 | train_acc=0.9020 | train_pixel_acc=0.9997 | epoch_time=11.0s | eta_total=00h01m27s | lr=0.000007
#
# Epoch 92 [###########################---]  92.5% ETA 00h01m22s
# Epoch 92 [###########################---]  93.0% ETA 00h01m16s
# epoch=92 | train_loss=0.0035 | train_acc=0.8693 | train_pixel_acc=0.9995 | epoch_time=11.0s | eta_total=00h01m16s | lr=0.000006
#
# Epoch 93 [############################--]  93.5% ETA 00h01m11s
# Epoch 93 [############################--]  94.0% ETA 00h01m05s
# epoch=93 | train_loss=0.0033 | train_acc=0.8693 | train_pixel_acc=0.9996 | epoch_time=10.9s | eta_total=00h01m05s | lr=0.000004
#
# Epoch 94 [############################--]  94.5% ETA 00h01m00s
# Epoch 94 [############################--]  95.0% ETA 00h00m54s
# epoch=94 | train_loss=0.0036 | train_acc=0.8366 | train_pixel_acc=0.9994 | epoch_time=10.9s | eta_total=00h00m54s | lr=0.000003
#
# Epoch 95 [############################--]  95.5% ETA 00h00m49s
# Epoch 95 [############################--]  96.0% ETA 00h00m43s
# epoch=95 | train_loss=0.0031 | train_acc=0.8497 | train_pixel_acc=0.9995 | epoch_time=10.9s | eta_total=00h00m43s | lr=0.000002
#
# Epoch 96 [############################--]  96.5% ETA 00h00m38s
# Epoch 96 [#############################-]  97.0% ETA 00h00m32s
# epoch=96 | train_loss=0.0027 | train_acc=0.8693 | train_pixel_acc=0.9995 | epoch_time=10.9s | eta_total=00h00m32s | lr=0.000001
#
# Epoch 97 [#############################-]  97.5% ETA 00h00m27s
# Epoch 97 [#############################-]  98.0% ETA 00h00m21s
# epoch=97 | train_loss=0.0031 | train_acc=0.8627 | train_pixel_acc=0.9994 | epoch_time=10.9s | eta_total=00h00m21s | lr=0.000001
#
# Epoch 98 [#############################-]  98.5% ETA 00h00m16s
# Epoch 98 [#############################-]  99.0% ETA 00h00m10s
# epoch=98 | train_loss=0.0029 | train_acc=0.8562 | train_pixel_acc=0.9994 | epoch_time=10.9s | eta_total=00h00m10s | lr=0.000000
#
# Epoch 99 [#############################-]  99.5% ETA 00h00m05s
# Epoch 99 [##############################] 100.0% ETA 00h00m00s
# epoch=99 | train_loss=0.0031 | train_acc=0.8693 | train_pixel_acc=0.9996 | epoch_time=11.0s | eta_total=00h00m00s | lr=0.000000
#
# Epoch 100 [##############################] 100.5% ETA 00h00m00s
# Epoch 100 [##############################] 101.0% ETA 00h00m00s
# epoch=100 | train_loss=0.0034 | train_acc=0.8758 | train_pixel_acc=0.9996 | epoch_time=11.0s | eta_total=00h00m00s | lr=0.000000
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:02,  2.52it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.04it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.24it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.35it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.41it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.45it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.32it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.64it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.60it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.54it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.55it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.54it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.53it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.53it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.42it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.88it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.54it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.56it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.57it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.56it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.54it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.55it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.45it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.89it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.59it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.54it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.53it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.54it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.52it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.53it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.43it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.88it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.57it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.57it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.58it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.57it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.54it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.55it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.45it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.90it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.56it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.57it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.57it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.57it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.56it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.55it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.45it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.90it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.53it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.54it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.53it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.55it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.54it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.55it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.45it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.89it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.51it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.51it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.52it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.53it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.54it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.53it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.43it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.87it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.54it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.52it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.54it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.54it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.53it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.53it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.42it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.87it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.55it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.54it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.54it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.54it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.53it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.54it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.44it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.88it/s]
# Oracle rank 1: 1.0. Cumulative: 1.0000
# Final Oracle Score: 1.0000
# Final Pass@1 Score: 1.0000
# Final Pass@2 Score: 1.0000
# Current task af24b4cc is Correct!✅
#   -> af24b4cc: pixel_acc=100.00%  exact_match=100.00%  (1 test pair(s))
#        pair 0: pixel_acc=100.00%  ✅
#
# ===== [2/30] TTT on task e1d2900e =====
# Running: /usr/bin/python3 test_time_train_ARC.py --epochs 100 --depth 10 --batch-size 8 --image-size 64 --patch-size 2 --learning-rate 0.0003 --weight-decay 0 --embed-dim 512 --num-heads 8 --num-colors 12 --resume-checkpoint /kaggle/input/datasets/rohan547/number2model/checkpoint_best.pt --resume-skip-task-token --lr-scheduler cosine --train-split eval_color_permute_ttt_9/e1d2900e --eval-split eval_color_permute_ttt_9/e1d2900e --data-root raw_data/ARC-AGI --architecture vit --eval-save-name ARC_1_eval_ViT --num-attempts 10 --ttt-num-each 1 --no-compile
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Start loading data...
# Finish loading!!
# Start loading data...
# Finish loading!!
# Total training examples: 153
# Resuming from checkpoint: /kaggle/input/datasets/rohan547/number2model/checkpoint_best.pt
# Patch size: 2, sequence length: 1024
# Skipped loading parameters: ['task_token_embed.weight']
# Starting test-time training attempt 1/1...
# Using automatic mixed precision (AMP) training
#
# Epoch 0 [------------------------------]   0.5% ETA 00h21m12s
# Epoch 0 [------------------------------]   1.0% ETA 00h19m11s
# epoch=0 | train_loss=0.1614 | train_acc=0.0000 | train_pixel_acc=0.9733 | epoch_time=11.6s | eta_total=00h19m12s | lr=0.000000
#
# Epoch 1 [------------------------------]   1.5% ETA 00h19m02s
# Epoch 1 [------------------------------]   2.0% ETA 00h18m33s
# epoch=1 | train_loss=0.1076 | train_acc=0.0000 | train_pixel_acc=0.9763 | epoch_time=11.1s | eta_total=00h18m33s | lr=0.000030
#
# Epoch 2 [------------------------------]   2.5% ETA 00h18m34s
# Epoch 2 [------------------------------]   3.0% ETA 00h18m18s
# epoch=2 | train_loss=0.0733 | train_acc=0.0000 | train_pixel_acc=0.9792 | epoch_time=11.2s | eta_total=00h18m18s | lr=0.000060
#
# Epoch 3 [#-----------------------------]   3.5% ETA 00h18m19s
# Epoch 3 [#-----------------------------]   4.0% ETA 00h18m06s
# epoch=3 | train_loss=0.0563 | train_acc=0.0000 | train_pixel_acc=0.9812 | epoch_time=11.3s | eta_total=00h18m06s | lr=0.000090
#
# Epoch 4 [#-----------------------------]   4.5% ETA 00h18m04s
# Epoch 4 [#-----------------------------]   5.0% ETA 00h17m51s
# epoch=4 | train_loss=0.0491 | train_acc=0.0000 | train_pixel_acc=0.9830 | epoch_time=11.2s | eta_total=00h17m51s | lr=0.000120
#
# Epoch 5 [#-----------------------------]   5.5% ETA 00h17m52s
# Epoch 5 [#-----------------------------]   6.0% ETA 00h17m40s
# epoch=5 | train_loss=0.0400 | train_acc=0.0000 | train_pixel_acc=0.9854 | epoch_time=11.3s | eta_total=00h17m40s | lr=0.000150
#
# Epoch 6 [#-----------------------------]   6.5% ETA 00h17m36s
# Epoch 6 [##----------------------------]   7.0% ETA 00h17m25s
# epoch=6 | train_loss=0.0348 | train_acc=0.0000 | train_pixel_acc=0.9872 | epoch_time=11.0s | eta_total=00h17m25s | lr=0.000180
#
# Epoch 7 [##----------------------------]   7.5% ETA 00h17m20s
# Epoch 7 [##----------------------------]   8.0% ETA 00h17m11s
# epoch=7 | train_loss=0.0336 | train_acc=0.0000 | train_pixel_acc=0.9877 | epoch_time=11.0s | eta_total=00h17m11s | lr=0.000210
#
# Epoch 8 [##----------------------------]   8.5% ETA 00h17m07s
# Epoch 8 [##----------------------------]   9.0% ETA 00h16m57s
# epoch=8 | train_loss=0.0272 | train_acc=0.0000 | train_pixel_acc=0.9897 | epoch_time=11.0s | eta_total=00h16m57s | lr=0.000240
#
# Epoch 9 [##----------------------------]   9.5% ETA 00h16m54s
# Epoch 9 [###---------------------------]  10.0% ETA 00h16m45s
# epoch=9 | train_loss=0.0234 | train_acc=0.0000 | train_pixel_acc=0.9913 | epoch_time=11.1s | eta_total=00h16m45s | lr=0.000270
#
# Epoch 10 [###---------------------------]  10.5% ETA 00h16m42s
# Epoch 10 [###---------------------------]  11.0% ETA 00h16m34s
# epoch=10 | train_loss=0.0204 | train_acc=0.0000 | train_pixel_acc=0.9925 | epoch_time=11.1s | eta_total=00h16m34s | lr=0.000300
#
# Epoch 11 [###---------------------------]  11.5% ETA 00h16m30s
# Epoch 11 [###---------------------------]  12.0% ETA 00h16m22s
# epoch=11 | train_loss=0.0180 | train_acc=0.0000 | train_pixel_acc=0.9934 | epoch_time=11.1s | eta_total=00h16m22s | lr=0.000300
#
# Epoch 12 [###---------------------------]  12.5% ETA 00h16m18s
# Epoch 12 [###---------------------------]  13.0% ETA 00h16m10s
# epoch=12 | train_loss=0.0167 | train_acc=0.0131 | train_pixel_acc=0.9939 | epoch_time=11.1s | eta_total=00h16m10s | lr=0.000300
#
# Epoch 13 [####--------------------------]  13.5% ETA 00h16m06s
# Epoch 13 [####--------------------------]  14.0% ETA 00h15m59s
# epoch=13 | train_loss=0.0138 | train_acc=0.0065 | train_pixel_acc=0.9952 | epoch_time=11.0s | eta_total=00h15m59s | lr=0.000299
#
# Epoch 14 [####--------------------------]  14.5% ETA 00h15m54s
# Epoch 14 [####--------------------------]  15.0% ETA 00h15m47s
# epoch=14 | train_loss=0.0135 | train_acc=0.0131 | train_pixel_acc=0.9952 | epoch_time=11.1s | eta_total=00h15m47s | lr=0.000299
#
# Epoch 15 [####--------------------------]  15.5% ETA 00h15m42s
# Epoch 15 [####--------------------------]  16.0% ETA 00h15m35s
# epoch=15 | train_loss=0.0116 | train_acc=0.0065 | train_pixel_acc=0.9956 | epoch_time=11.0s | eta_total=00h15m35s | lr=0.000298
#
# Epoch 16 [####--------------------------]  16.5% ETA 00h15m31s
# Epoch 16 [#####-------------------------]  17.0% ETA 00h15m23s
# epoch=16 | train_loss=0.0136 | train_acc=0.0131 | train_pixel_acc=0.9953 | epoch_time=11.0s | eta_total=00h15m23s | lr=0.000297
#
# Epoch 17 [#####-------------------------]  17.5% ETA 00h15m19s
# Epoch 17 [#####-------------------------]  18.0% ETA 00h15m12s
# epoch=17 | train_loss=0.0104 | train_acc=0.0261 | train_pixel_acc=0.9964 | epoch_time=11.0s | eta_total=00h15m12s | lr=0.000296
#
# Epoch 18 [#####-------------------------]  18.5% ETA 00h15m07s
# Epoch 18 [#####-------------------------]  19.0% ETA 00h15m00s
# epoch=18 | train_loss=0.0096 | train_acc=0.0196 | train_pixel_acc=0.9967 | epoch_time=11.0s | eta_total=00h15m00s | lr=0.000294
#
# Epoch 19 [#####-------------------------]  19.5% ETA 00h14m56s
# Epoch 19 [######------------------------]  20.0% ETA 00h14m49s
# epoch=19 | train_loss=0.0086 | train_acc=0.0458 | train_pixel_acc=0.9971 | epoch_time=11.0s | eta_total=00h14m49s | lr=0.000293
#
# Epoch 20 [######------------------------]  20.5% ETA 00h14m44s
# Epoch 20 [######------------------------]  21.0% ETA 00h14m38s
# epoch=20 | train_loss=0.0123 | train_acc=0.0392 | train_pixel_acc=0.9957 | epoch_time=11.0s | eta_total=00h14m38s | lr=0.000291
#
# Epoch 21 [######------------------------]  21.5% ETA 00h14m33s
# Epoch 21 [######------------------------]  22.0% ETA 00h14m26s
# epoch=21 | train_loss=0.0096 | train_acc=0.0654 | train_pixel_acc=0.9969 | epoch_time=11.1s | eta_total=00h14m26s | lr=0.000289
#
# Epoch 22 [######------------------------]  22.5% ETA 00h14m21s
# Epoch 22 [######------------------------]  23.0% ETA 00h14m15s
# epoch=22 | train_loss=0.0076 | train_acc=0.0654 | train_pixel_acc=0.9975 | epoch_time=11.0s | eta_total=00h14m15s | lr=0.000287
#
# Epoch 23 [#######-----------------------]  23.5% ETA 00h14m10s
# Epoch 23 [#######-----------------------]  24.0% ETA 00h14m04s
# epoch=23 | train_loss=0.0079 | train_acc=0.0654 | train_pixel_acc=0.9976 | epoch_time=11.1s | eta_total=00h14m04s | lr=0.000285
#
# Epoch 24 [#######-----------------------]  24.5% ETA 00h13m59s
# Epoch 24 [#######-----------------------]  25.0% ETA 00h13m52s
# epoch=24 | train_loss=0.0075 | train_acc=0.0392 | train_pixel_acc=0.9974 | epoch_time=11.1s | eta_total=00h13m52s | lr=0.000282
#
# Epoch 25 [#######-----------------------]  25.5% ETA 00h13m48s
# Epoch 25 [#######-----------------------]  26.0% ETA 00h13m41s
# epoch=25 | train_loss=0.0066 | train_acc=0.0850 | train_pixel_acc=0.9978 | epoch_time=11.1s | eta_total=00h13m41s | lr=0.000280
#
# Epoch 26 [#######-----------------------]  26.5% ETA 00h13m36s
# Epoch 26 [########----------------------]  27.0% ETA 00h13m30s
# epoch=26 | train_loss=0.0064 | train_acc=0.1307 | train_pixel_acc=0.9980 | epoch_time=11.1s | eta_total=00h13m30s | lr=0.000277
#
# Epoch 27 [########----------------------]  27.5% ETA 00h13m25s
# Epoch 27 [########----------------------]  28.0% ETA 00h13m19s
# epoch=27 | train_loss=0.0058 | train_acc=0.1176 | train_pixel_acc=0.9982 | epoch_time=11.1s | eta_total=00h13m19s | lr=0.000274
#
# Epoch 28 [########----------------------]  28.5% ETA 00h13m14s
# Epoch 28 [########----------------------]  29.0% ETA 00h13m08s
# epoch=28 | train_loss=0.0057 | train_acc=0.0850 | train_pixel_acc=0.9982 | epoch_time=11.0s | eta_total=00h13m08s | lr=0.000271
#
# Epoch 29 [########----------------------]  29.5% ETA 00h13m03s
# Epoch 29 [#########---------------------]  30.0% ETA 00h12m56s
# epoch=29 | train_loss=0.0049 | train_acc=0.1503 | train_pixel_acc=0.9985 | epoch_time=11.1s | eta_total=00h12m56s | lr=0.000268
#
# Epoch 30 [#########---------------------]  30.5% ETA 00h12m51s
# Epoch 30 [#########---------------------]  31.0% ETA 00h12m45s
# epoch=30 | train_loss=0.0054 | train_acc=0.1503 | train_pixel_acc=0.9984 | epoch_time=11.1s | eta_total=00h12m45s | lr=0.000265
#
# Epoch 31 [#########---------------------]  31.5% ETA 00h12m40s
# Epoch 31 [#########---------------------]  32.0% ETA 00h12m34s
# epoch=31 | train_loss=0.0046 | train_acc=0.2092 | train_pixel_acc=0.9986 | epoch_time=11.0s | eta_total=00h12m34s | lr=0.000261
#
# Epoch 32 [#########---------------------]  32.5% ETA 00h12m29s
# Epoch 32 [#########---------------------]  33.0% ETA 00h12m23s
# epoch=32 | train_loss=0.0049 | train_acc=0.1176 | train_pixel_acc=0.9985 | epoch_time=11.0s | eta_total=00h12m23s | lr=0.000258
#
# Epoch 33 [##########--------------------]  33.5% ETA 00h12m18s
# Epoch 33 [##########--------------------]  34.0% ETA 00h12m12s
# epoch=33 | train_loss=0.0045 | train_acc=0.2157 | train_pixel_acc=0.9988 | epoch_time=11.0s | eta_total=00h12m12s | lr=0.000254
#
# Epoch 34 [##########--------------------]  34.5% ETA 00h12m07s
# Epoch 34 [##########--------------------]  35.0% ETA 00h12m00s
# epoch=34 | train_loss=0.0057 | train_acc=0.1634 | train_pixel_acc=0.9982 | epoch_time=11.0s | eta_total=00h12m00s | lr=0.000250
#
# Epoch 35 [##########--------------------]  35.5% ETA 00h11m55s
# Epoch 35 [##########--------------------]  36.0% ETA 00h11m49s
# epoch=35 | train_loss=0.0046 | train_acc=0.1895 | train_pixel_acc=0.9986 | epoch_time=11.0s | eta_total=00h11m49s | lr=0.000246
#
# Epoch 36 [##########--------------------]  36.5% ETA 00h11m44s
# Epoch 36 [###########-------------------]  37.0% ETA 00h11m38s
# epoch=36 | train_loss=0.0036 | train_acc=0.2288 | train_pixel_acc=0.9989 | epoch_time=11.0s | eta_total=00h11m38s | lr=0.000242
#
# Epoch 37 [###########-------------------]  37.5% ETA 00h11m33s
# Epoch 37 [###########-------------------]  38.0% ETA 00h11m27s
# epoch=37 | train_loss=0.0038 | train_acc=0.3007 | train_pixel_acc=0.9990 | epoch_time=11.1s | eta_total=00h11m27s | lr=0.000238
#
# Epoch 38 [###########-------------------]  38.5% ETA 00h11m22s
# Epoch 38 [###########-------------------]  39.0% ETA 00h11m16s
# epoch=38 | train_loss=0.0031 | train_acc=0.3137 | train_pixel_acc=0.9991 | epoch_time=11.0s | eta_total=00h11m16s | lr=0.000234
#
# Epoch 39 [###########-------------------]  39.5% ETA 00h11m11s
# Epoch 39 [############------------------]  40.0% ETA 00h11m05s
# epoch=39 | train_loss=0.0034 | train_acc=0.2876 | train_pixel_acc=0.9991 | epoch_time=11.0s | eta_total=00h11m05s | lr=0.000229
#
# Epoch 40 [############------------------]  40.5% ETA 00h10m59s
# Epoch 40 [############------------------]  41.0% ETA 00h10m54s
# epoch=40 | train_loss=0.0034 | train_acc=0.2680 | train_pixel_acc=0.9990 | epoch_time=11.1s | eta_total=00h10m54s | lr=0.000225
#
# Epoch 41 [############------------------]  41.5% ETA 00h10m48s
# Epoch 41 [############------------------]  42.0% ETA 00h10m42s
# epoch=41 | train_loss=0.0028 | train_acc=0.3791 | train_pixel_acc=0.9992 | epoch_time=11.0s | eta_total=00h10m42s | lr=0.000220
#
# Epoch 42 [############------------------]  42.5% ETA 00h10m37s
# Epoch 42 [############------------------]  43.0% ETA 00h10m31s
# epoch=42 | train_loss=0.0027 | train_acc=0.3660 | train_pixel_acc=0.9993 | epoch_time=11.0s | eta_total=00h10m31s | lr=0.000216
#
# Epoch 43 [#############-----------------]  43.5% ETA 00h10m26s
# Epoch 43 [#############-----------------]  44.0% ETA 00h10m20s
# epoch=43 | train_loss=0.0026 | train_acc=0.3725 | train_pixel_acc=0.9993 | epoch_time=11.0s | eta_total=00h10m20s | lr=0.000211
#
# Epoch 44 [#############-----------------]  44.5% ETA 00h10m15s
# Epoch 44 [#############-----------------]  45.0% ETA 00h10m09s
# epoch=44 | train_loss=0.0024 | train_acc=0.4118 | train_pixel_acc=0.9993 | epoch_time=11.0s | eta_total=00h10m09s | lr=0.000206
#
# Epoch 45 [#############-----------------]  45.5% ETA 00h10m04s
# Epoch 45 [#############-----------------]  46.0% ETA 00h09m58s
# epoch=45 | train_loss=0.0022 | train_acc=0.4248 | train_pixel_acc=0.9995 | epoch_time=11.1s | eta_total=00h09m58s | lr=0.000201
#
# Epoch 46 [#############-----------------]  46.5% ETA 00h09m53s
# Epoch 46 [##############----------------]  47.0% ETA 00h09m47s
# epoch=46 | train_loss=0.0024 | train_acc=0.4314 | train_pixel_acc=0.9994 | epoch_time=11.0s | eta_total=00h09m47s | lr=0.000196
#
# Epoch 47 [##############----------------]  47.5% ETA 00h09m42s
# Epoch 47 [##############----------------]  48.0% ETA 00h09m36s
# epoch=47 | train_loss=0.0017 | train_acc=0.4510 | train_pixel_acc=0.9995 | epoch_time=11.1s | eta_total=00h09m36s | lr=0.000191
#
# Epoch 48 [##############----------------]  48.5% ETA 00h09m30s
# Epoch 48 [##############----------------]  49.0% ETA 00h09m25s
# epoch=48 | train_loss=0.0019 | train_acc=0.4575 | train_pixel_acc=0.9995 | epoch_time=11.0s | eta_total=00h09m25s | lr=0.000186
#
# Epoch 49 [##############----------------]  49.5% ETA 00h09m19s
# Epoch 49 [###############---------------]  50.0% ETA 00h09m13s
# epoch=49 | train_loss=0.0016 | train_acc=0.5425 | train_pixel_acc=0.9996 | epoch_time=11.0s | eta_total=00h09m13s | lr=0.000181
#
# Epoch 50 [###############---------------]  50.5% ETA 00h09m08s
# Epoch 50 [###############---------------]  51.0% ETA 00h09m02s
# epoch=50 | train_loss=0.0015 | train_acc=0.5556 | train_pixel_acc=0.9996 | epoch_time=11.1s | eta_total=00h09m02s | lr=0.000176
#
# Epoch 51 [###############---------------]  51.5% ETA 00h08m57s
# Epoch 51 [###############---------------]  52.0% ETA 00h08m51s
# ...
# Epoch 55 [################--------------]  56.0% ETA 00h08m06s
# epoch=55 | train_loss=0.0314 | train_acc=0.0784 | train_pixel_acc=0.9894 | epoch_time=11.0s | eta_total=00h08m06s | lr=0.000150
#
# Epoch 56 [################--------------]  56.5% ETA 00h08m00s
# Epoch 56 [#################-------------]  57.0% ETA 00h07m55s
# epoch=56 | train_loss=0.0319 | train_acc=0.1046 | train_pixel_acc=0.9897 | epoch_time=11.0s | eta_total=00h07m55s | lr=0.000145
#
# Epoch 57 [#################-------------]  57.5% ETA 00h07m49s
# Epoch 57 [#################-------------]  58.0% ETA 00h07m44s
# epoch=57 | train_loss=0.0273 | train_acc=0.0915 | train_pixel_acc=0.9906 | epoch_time=11.0s | eta_total=00h07m44s | lr=0.000140
#
# Epoch 58 [#################-------------]  58.5% ETA 00h07m38s
# Epoch 58 [#################-------------]  59.0% ETA 00h07m33s
# epoch=58 | train_loss=0.0232 | train_acc=0.1242 | train_pixel_acc=0.9923 | epoch_time=11.0s | eta_total=00h07m33s | lr=0.000134
#
# Epoch 59 [#################-------------]  59.5% ETA 00h07m27s
# Epoch 59 [##################------------]  60.0% ETA 00h07m21s
# epoch=59 | train_loss=0.0274 | train_acc=0.1046 | train_pixel_acc=0.9906 | epoch_time=11.0s | eta_total=00h07m21s | lr=0.000129
#
# Epoch 60 [##################------------]  60.5% ETA 00h07m16s
# Epoch 60 [##################------------]  61.0% ETA 00h07m10s
# epoch=60 | train_loss=0.0260 | train_acc=0.1699 | train_pixel_acc=0.9915 | epoch_time=11.0s | eta_total=00h07m10s | lr=0.000124
#
# Epoch 61 [##################------------]  61.5% ETA 00h07m05s
# Epoch 61 [##################------------]  62.0% ETA 00h06m59s
# epoch=61 | train_loss=0.0246 | train_acc=0.2157 | train_pixel_acc=0.9921 | epoch_time=11.0s | eta_total=00h06m59s | lr=0.000119
#
# Epoch 62 [##################------------]  62.5% ETA 00h06m54s
# Epoch 62 [##################------------]  63.0% ETA 00h06m48s
# epoch=62 | train_loss=0.0246 | train_acc=0.1373 | train_pixel_acc=0.9918 | epoch_time=11.0s | eta_total=00h06m48s | lr=0.000114
#
# Epoch 63 [###################-----------]  63.5% ETA 00h06m43s
# Epoch 63 [###################-----------]  64.0% ETA 00h06m37s
# epoch=63 | train_loss=0.0262 | train_acc=0.1111 | train_pixel_acc=0.9918 | epoch_time=11.0s | eta_total=00h06m37s | lr=0.000109
#
# Epoch 64 [###################-----------]  64.5% ETA 00h06m32s
# Epoch 64 [###################-----------]  65.0% ETA 00h06m26s
# epoch=64 | train_loss=0.0234 | train_acc=0.1242 | train_pixel_acc=0.9921 | epoch_time=11.0s | eta_total=00h06m26s | lr=0.000104
#
# Epoch 65 [###################-----------]  65.5% ETA 00h06m21s
# Epoch 65 [###################-----------]  66.0% ETA 00h06m15s
# epoch=65 | train_loss=0.0264 | train_acc=0.1242 | train_pixel_acc=0.9914 | epoch_time=11.0s | eta_total=00h06m15s | lr=0.000099
#
# Epoch 66 [###################-----------]  66.5% ETA 00h06m10s
# Epoch 66 [####################----------]  67.0% ETA 00h06m04s
# epoch=66 | train_loss=0.0228 | train_acc=0.1307 | train_pixel_acc=0.9931 | epoch_time=11.0s | eta_total=00h06m04s | lr=0.000094
#
# Epoch 67 [####################----------]  67.5% ETA 00h05m59s
# Epoch 67 [####################----------]  68.0% ETA 00h05m53s
# epoch=67 | train_loss=0.0176 | train_acc=0.2157 | train_pixel_acc=0.9943 | epoch_time=11.0s | eta_total=00h05m53s | lr=0.000089
#
# Epoch 68 [####################----------]  68.5% ETA 00h05m48s
# Epoch 68 [####################----------]  69.0% ETA 00h05m42s
# epoch=68 | train_loss=0.0179 | train_acc=0.1765 | train_pixel_acc=0.9944 | epoch_time=11.0s | eta_total=00h05m42s | lr=0.000084
#
# Epoch 69 [####################----------]  69.5% ETA 00h05m37s
# Epoch 69 [#####################---------]  70.0% ETA 00h05m31s
# epoch=69 | train_loss=0.0175 | train_acc=0.1503 | train_pixel_acc=0.9943 | epoch_time=11.0s | eta_total=00h05m31s | lr=0.000080
#
# Epoch 70 [#####################---------]  70.5% ETA 00h05m25s
# Epoch 70 [#####################---------]  71.0% ETA 00h05m20s
# epoch=70 | train_loss=0.0164 | train_acc=0.2353 | train_pixel_acc=0.9947 | epoch_time=11.0s | eta_total=00h05m20s | lr=0.000075
#
# Epoch 71 [#####################---------]  71.5% ETA 00h05m14s
# Epoch 71 [#####################---------]  72.0% ETA 00h05m09s
# epoch=71 | train_loss=0.0192 | train_acc=0.1895 | train_pixel_acc=0.9941 | epoch_time=11.0s | eta_total=00h05m09s | lr=0.000071
#
# Epoch 72 [#####################---------]  72.5% ETA 00h05m03s
# Epoch 72 [#####################---------]  73.0% ETA 00h04m58s
# epoch=72 | train_loss=0.0192 | train_acc=0.2157 | train_pixel_acc=0.9933 | epoch_time=11.0s | eta_total=00h04m58s | lr=0.000066
#
# Epoch 73 [######################--------]  73.5% ETA 00h04m52s
# Epoch 73 [######################--------]  74.0% ETA 00h04m47s
# epoch=73 | train_loss=0.0210 | train_acc=0.1961 | train_pixel_acc=0.9937 | epoch_time=11.0s | eta_total=00h04m47s | lr=0.000062
#
# Epoch 74 [######################--------]  74.5% ETA 00h04m41s
# Epoch 74 [######################--------]  75.0% ETA 00h04m36s
# epoch=74 | train_loss=0.0186 | train_acc=0.2353 | train_pixel_acc=0.9944 | epoch_time=11.0s | eta_total=00h04m36s | lr=0.000058
#
# Epoch 75 [######################--------]  75.5% ETA 00h04m30s
# Epoch 75 [######################--------]  76.0% ETA 00h04m25s
# epoch=75 | train_loss=0.0181 | train_acc=0.2484 | train_pixel_acc=0.9947 | epoch_time=11.0s | eta_total=00h04m25s | lr=0.000054
#
# Epoch 76 [######################--------]  76.5% ETA 00h04m19s
# Epoch 76 [#######################-------]  77.0% ETA 00h04m13s
# epoch=76 | train_loss=0.0171 | train_acc=0.2614 | train_pixel_acc=0.9946 | epoch_time=11.0s | eta_total=00h04m13s | lr=0.000050
#
# Epoch 77 [#######################-------]  77.5% ETA 00h04m08s
# Epoch 77 [#######################-------]  78.0% ETA 00h04m02s
# epoch=77 | train_loss=0.0174 | train_acc=0.2549 | train_pixel_acc=0.9944 | epoch_time=11.0s | eta_total=00h04m02s | lr=0.000046
#
# Epoch 78 [#######################-------]  78.5% ETA 00h03m57s
# Epoch 78 [#######################-------]  79.0% ETA 00h03m51s
# epoch=78 | train_loss=0.0162 | train_acc=0.2353 | train_pixel_acc=0.9951 | epoch_time=11.0s | eta_total=00h03m51s | lr=0.000042
#
# Epoch 79 [#######################-------]  79.5% ETA 00h03m46s
# Epoch 79 [########################------]  80.0% ETA 00h03m40s
# epoch=79 | train_loss=0.0168 | train_acc=0.1961 | train_pixel_acc=0.9946 | epoch_time=11.0s | eta_total=00h03m40s | lr=0.000039
#
# Epoch 80 [########################------]  80.5% ETA 00h03m35s
# Epoch 80 [########################------]  81.0% ETA 00h03m29s
# epoch=80 | train_loss=0.0159 | train_acc=0.2353 | train_pixel_acc=0.9949 | epoch_time=11.0s | eta_total=00h03m29s | lr=0.000035
#
# Epoch 81 [########################------]  81.5% ETA 00h03m24s
# Epoch 81 [########################------]  82.0% ETA 00h03m18s
# epoch=81 | train_loss=0.0150 | train_acc=0.2484 | train_pixel_acc=0.9951 | epoch_time=11.0s | eta_total=00h03m18s | lr=0.000032
#
# Epoch 82 [########################------]  82.5% ETA 00h03m13s
# Epoch 82 [########################------]  83.0% ETA 00h03m07s
# epoch=82 | train_loss=0.0148 | train_acc=0.2353 | train_pixel_acc=0.9957 | epoch_time=11.0s | eta_total=00h03m07s | lr=0.000029
#
# Epoch 83 [#########################-----]  83.5% ETA 00h03m02s
# Epoch 83 [#########################-----]  84.0% ETA 00h02m56s
# epoch=83 | train_loss=0.0152 | train_acc=0.2614 | train_pixel_acc=0.9956 | epoch_time=11.0s | eta_total=00h02m56s | lr=0.000026
#
# Epoch 84 [#########################-----]  84.5% ETA 00h02m51s
# Epoch 84 [#########################-----]  85.0% ETA 00h02m45s
# epoch=84 | train_loss=0.0159 | train_acc=0.2549 | train_pixel_acc=0.9953 | epoch_time=11.0s | eta_total=00h02m45s | lr=0.000023
#
# Epoch 85 [#########################-----]  85.5% ETA 00h02m40s
# Epoch 85 [#########################-----]  86.0% ETA 00h02m34s
# epoch=85 | train_loss=0.0149 | train_acc=0.2092 | train_pixel_acc=0.9952 | epoch_time=11.0s | eta_total=00h02m34s | lr=0.000020
#
# Epoch 86 [#########################-----]  86.5% ETA 00h02m29s
# Epoch 86 [##########################----]  87.0% ETA 00h02m23s
# epoch=86 | train_loss=0.0141 | train_acc=0.2614 | train_pixel_acc=0.9959 | epoch_time=11.0s | eta_total=00h02m23s | lr=0.000018
#
# Epoch 87 [##########################----]  87.5% ETA 00h02m18s
# Epoch 87 [##########################----]  88.0% ETA 00h02m12s
# epoch=87 | train_loss=0.0122 | train_acc=0.2484 | train_pixel_acc=0.9960 | epoch_time=11.0s | eta_total=00h02m12s | lr=0.000015
#
# Epoch 88 [##########################----]  88.5% ETA 00h02m06s
# Epoch 88 [##########################----]  89.0% ETA 00h02m01s
# epoch=88 | train_loss=0.0175 | train_acc=0.2484 | train_pixel_acc=0.9947 | epoch_time=11.0s | eta_total=00h02m01s | lr=0.000013
#
# Epoch 89 [##########################----]  89.5% ETA 00h01m55s
# Epoch 89 [###########################---]  90.0% ETA 00h01m50s
# epoch=89 | train_loss=0.0147 | train_acc=0.2288 | train_pixel_acc=0.9951 | epoch_time=11.0s | eta_total=00h01m50s | lr=0.000011
#
# Epoch 90 [###########################---]  90.5% ETA 00h01m44s
# Epoch 90 [###########################---]  91.0% ETA 00h01m39s
# epoch=90 | train_loss=0.0148 | train_acc=0.3137 | train_pixel_acc=0.9954 | epoch_time=11.0s | eta_total=00h01m39s | lr=0.000009
#
# Epoch 91 [###########################---]  91.5% ETA 00h01m33s
# Epoch 91 [###########################---]  92.0% ETA 00h01m28s
# epoch=91 | train_loss=0.0127 | train_acc=0.2810 | train_pixel_acc=0.9965 | epoch_time=11.0s | eta_total=00h01m28s | lr=0.000007
#
# Epoch 92 [###########################---]  92.5% ETA 00h01m22s
# Epoch 92 [###########################---]  93.0% ETA 00h01m17s
# epoch=92 | train_loss=0.0135 | train_acc=0.2941 | train_pixel_acc=0.9954 | epoch_time=11.0s | eta_total=00h01m17s | lr=0.000006
#
# Epoch 93 [############################--]  93.5% ETA 00h01m11s
# Epoch 93 [############################--]  94.0% ETA 00h01m06s
# epoch=93 | train_loss=0.0112 | train_acc=0.3268 | train_pixel_acc=0.9965 | epoch_time=11.0s | eta_total=00h01m06s | lr=0.000004
#
# Epoch 94 [############################--]  94.5% ETA 00h01m00s
# Epoch 94 [############################--]  95.0% ETA 00h00m55s
# epoch=94 | train_loss=0.0143 | train_acc=0.2484 | train_pixel_acc=0.9955 | epoch_time=11.0s | eta_total=00h00m55s | lr=0.000003
#
# Epoch 95 [############################--]  95.5% ETA 00h00m49s
# Epoch 95 [############################--]  96.0% ETA 00h00m44s
# epoch=95 | train_loss=0.0101 | train_acc=0.2484 | train_pixel_acc=0.9967 | epoch_time=11.0s | eta_total=00h00m44s | lr=0.000002
#
# Epoch 96 [############################--]  96.5% ETA 00h00m38s
# Epoch 96 [#############################-]  97.0% ETA 00h00m33s
# epoch=96 | train_loss=0.0170 | train_acc=0.2484 | train_pixel_acc=0.9945 | epoch_time=11.0s | eta_total=00h00m33s | lr=0.000001
#
# Epoch 97 [#############################-]  97.5% ETA 00h00m27s
# Epoch 97 [#############################-]  98.0% ETA 00h00m22s
# epoch=97 | train_loss=0.0156 | train_acc=0.3072 | train_pixel_acc=0.9953 | epoch_time=11.0s | eta_total=00h00m22s | lr=0.000001
#
# Epoch 98 [#############################-]  98.5% ETA 00h00m16s
# Epoch 98 [#############################-]  99.0% ETA 00h00m11s
# epoch=98 | train_loss=0.0109 | train_acc=0.3072 | train_pixel_acc=0.9963 | epoch_time=11.0s | eta_total=00h00m11s | lr=0.000000
#
# Epoch 99 [#############################-]  99.5% ETA 00h00m05s
# Epoch 99 [##############################] 100.0% ETA 00h00m00s
# epoch=99 | train_loss=0.0148 | train_acc=0.2353 | train_pixel_acc=0.9953 | epoch_time=11.0s | eta_total=00h00m00s | lr=0.000000
#
# Epoch 100 [##############################] 100.5% ETA 00h00m00s
# Epoch 100 [##############################] 101.0% ETA 00h00m00s
# epoch=100 | train_loss=0.0169 | train_acc=0.2092 | train_pixel_acc=0.9945 | epoch_time=11.0s | eta_total=00h00m00s | lr=0.000000
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:02,  2.88it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.21it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.30it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.35it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.38it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.39it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.29it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.67it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.48it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.50it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.50it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.47it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.50it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.50it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.40it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.84it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.56it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.51it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.54it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.50it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.49it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.51it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.40it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.85it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.58it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.54it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.54it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.53it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.52it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.49it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.39it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.86it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.55it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.51it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.52it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.50it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.50it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.52it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.40it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.85it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.51it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.49it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.51it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.53it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.50it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.49it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.38it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.84it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.51it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.46it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.48it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.49it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.50it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.52it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.41it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.84it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.47it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.46it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.49it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.46it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.48it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.48it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.38it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.82it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.48it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.48it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.50it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.49it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.48it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.47it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.38it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.83it/s]
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:00<00:01,  3.50it/s]
#  29%|██▊       | 2/7 [00:00<00:01,  3.47it/s]
#  43%|████▎     | 3/7 [00:00<00:01,  3.48it/s]
#  57%|█████▋    | 4/7 [00:01<00:00,  3.49it/s]
#  71%|███████▏  | 5/7 [00:01<00:00,  3.46it/s]
#  86%|████████▌ | 6/7 [00:01<00:00,  3.47it/s]
# 100%|██████████| 7/7 [00:01<00:00,  4.37it/s]
# 100%|██████████| 7/7 [00:01<00:00,  3.82it/s]
# Final Oracle Score: 0.0000
# Final Pass@1 Score: 0.0000
# Final Pass@2 Score: 0.0000
# Current task fd4b2b02 is Wrong!❌
#   -> fd4b2b02: pixel_acc=79.69%  exact_match=0.00%  (1 test pair(s))
#        pair 0: pixel_acc= 79.69%  ❌
#
# TTT finished for 30 task(s) in 621.4 min

# %% [markdown]
# ## 8. Aggregate results
#
# Merges predictions across the `TTT_NUM_EACH` independent TTT runs per task and computes overall
# Pass@1 / Pass@2 / Oracle, the same scoring logic as the repo's `utils/analyze_prediction.py` /
# `analysis.py` (majority vote via `get_majority_vote`), generalized to whatever `TTT_TASKS` you ran.

# %%
import os, json
import numpy as np
from utils.eval_utils import get_majority_vote

def collect_final_results(task_list, save_name, num_each, data_root):
    task_type = data_root.split("/")[-1]
    all_task_num = correct_1 = correct_2 = correct_oracle = 0
    total_correct_px = total_px = total_exact = total_pairs = 0
    per_task_scores = {}

    print(f"{'Task ID':<12} | {'Pass@1':<7} | {'Pass@2':<7} | {'Oracle':<7} | {'PixelAcc':<9} | {'ExactAcc'}")
    print("-" * 72)

    for task_name in task_list:
        merged = None
        for i in range(num_each):
            fp = f"outputs/{save_name}_attempt_{i}/{task_name}_predictions.json"
            if not os.path.exists(fp):
                continue
            with open(fp) as f:
                d = json.load(f)
            if merged is None:
                merged = {k: list(v) for k, v in d.items()}
            else:
                for k, v in d.items():
                    merged.setdefault(k, [])
                    merged[k] += v
        if merged is None:
            print(f"{task_name:<12} | [no predictions found, skipping]")
            continue

        gt_path = f"raw_data/{task_type}/data/evaluation/{task_name}.json"
        with open(gt_path) as f:
            gt_data = json.load(f)
        ground_truth = {str(i): item["output"] for i, item in enumerate(gt_data["test"])}

        n_examples = len(merged)
        t1 = t2 = torac = 0
        task_correct_px = task_total_px = task_exact = 0

        for idx_str, preds in merged.items():
            mv = get_majority_vote(preds)
            gt = ground_truth[str(idx_str)]
            gt_arr = np.array(gt)

            p1 = bool(mv) and mv[0]["prediction"] == gt
            p2 = p1 or (len(mv) > 1 and mv[1]["prediction"] == gt)
            oracle = any(e["prediction"] == gt for e in mv)
            t1 += p1; t2 += p2; torac += oracle

            pred_arr = np.array(mv[0]["prediction"]) if mv else None
            if pred_arr is not None and pred_arr.shape == gt_arr.shape:
                correct = int(np.sum(pred_arr == gt_arr))
            elif pred_arr is not None:
                min_h = min(gt_arr.shape[0], pred_arr.shape[0])
                min_w = min(gt_arr.shape[1], pred_arr.shape[1])
                correct = int(np.sum(gt_arr[:min_h, :min_w] == pred_arr[:min_h, :min_w])) if min_h > 0 and min_w > 0 else 0
            else:
                correct = 0

            task_correct_px += correct
            task_total_px += gt_arr.size
            task_exact += int(p1)

        task_pass1, task_pass2, task_oracle = t1 / max(n_examples, 1), t2 / max(n_examples, 1), torac / max(n_examples, 1)
        task_pixel_acc = task_correct_px / max(task_total_px, 1) * 100
        task_exact_acc = task_exact / max(n_examples, 1) * 100

        per_task_scores[task_name] = dict(pass_at_1=task_pass1, pass_at_2=task_pass2, oracle=task_oracle,
                                           pixel_acc=task_pixel_acc, exact_acc=task_exact_acc)

        all_task_num += 1
        correct_1 += task_pass1; correct_2 += task_pass2; correct_oracle += task_oracle
        total_correct_px += task_correct_px; total_px += task_total_px
        total_exact += task_exact; total_pairs += n_examples

        print(f"{task_name:<12} | {task_pass1:<7.2f} | {task_pass2:<7.2f} | {task_oracle:<7.2f} | {task_pixel_acc:<8.2f}% | {task_exact_acc:.2f}%")

    print("=" * 72)
    if all_task_num:
        overall_pixel_acc = total_correct_px / max(total_px, 1) * 100
        overall_exact_acc = total_exact / max(total_pairs, 1) * 100
        print(f"\n==== Aggregate over {all_task_num} task(s), {total_pairs} test pair(s) ====")
        print(f"Pass@1              : {correct_1/all_task_num:.4f}")
        print(f"Pass@2              : {correct_2/all_task_num:.4f}")
        print(f"Oracle              : {correct_oracle/all_task_num:.4f}")
        print(f"Overall Pixel Acc   : {overall_pixel_acc:.2f}%  ({total_correct_px}/{total_px} pixels)")
        print(f"Overall Exact Match : {overall_exact_acc:.2f}%  ({total_exact}/{total_pairs} pairs)")
    return per_task_scores

final_scores = collect_final_results(TTT_TASKS, TTT_EVAL_SAVE_NAME, TTT_NUM_EACH, DATA_ROOT)
# Out:
# Task ID      | Pass@1  | Pass@2  | Oracle  | PixelAcc  | ExactAcc
# ------------------------------------------------------------------------
# af24b4cc     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# e1d2900e     | 0.00    | 0.00    | 0.00    | 99.44   % | 0.00%
# 903d1b4a     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# 4e469f39     | 0.00    | 0.00    | 0.00    | 92.00   % | 0.00%
# b1fc8b8e     | 0.00    | 0.00    | 0.50    | 84.00   % | 0.00%
# 2c737e39     | 0.00    | 0.00    | 0.00    | 90.91   % | 0.00%
# 992798f6     | 0.00    | 0.00    | 0.00    | 92.97   % | 0.00%
# 00576224     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# 48131b3c     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# 60a26a3e     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# 59341089     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# 31d5ba1a     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# e633a9e5     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# 62ab2642     | 0.00    | 0.00    | 1.00    | 96.67   % | 0.00%
# 73c3b0d8     | 0.00    | 0.00    | 0.00    | 90.62   % | 0.00%
# c663677b     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# c48954c1     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# 08573cc6     | 0.00    | 0.00    | 0.00    | 63.31   % | 0.00%
# 136b0064     | 0.00    | 0.00    | 0.00    | 72.18   % | 0.00%
# 929ab4e9     | 0.00    | 0.00    | 0.00    | 96.88   % | 0.00%
# 5b526a93     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# ef26cbf6     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# fafd9572     | 0.00    | 0.00    | 0.00    | 85.71   % | 0.00%
# 67c52801     | 0.00    | 0.00    | 0.00    | 92.21   % | 0.00%
# ad7e01d0     | 0.00    | 0.00    | 0.00    | 37.12   % | 0.00%
# 506d28a5     | 0.00    | 0.00    | 1.00    | 85.00   % | 0.00%
# 27a77e38     | 0.00    | 0.00    | 1.00    | 98.77   % | 0.00%
# d492a647     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# 72a961c9     | 1.00    | 1.00    | 1.00    | 100.00  % | 100.00%
# fd4b2b02     | 0.00    | 0.00    | 0.00    | 79.69   % | 0.00%
# ========================================================================
#
# ==== Aggregate over 30 task(s), 32 test pair(s) ====
# Pass@1              : 0.4667
# Pass@2              : 0.4667
# Oracle              : 0.5833
# Overall Pixel Acc   : 89.33%  (5494/6150 pixels)
# Overall Exact Match : 46.88%  (15/32 pairs)

# %% [markdown]
# # **Visualization of results**
# personal visualizer - it can take input the predicted files from above runs and then display input, ground truth and predicted grid together
# NOTE - only for personal use and not to be done along with the above model

# %%
import os, json
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from utils.eval_utils import get_majority_vote

arc_cmap = colors.ListedColormap(['#000000', '#0074D9', '#FF4136', '#2ECC40', '#FFDC00',
                                   '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
norm = colors.Normalize(vmin=0, vmax=9)

def plot_grid(ax, grid, title):
    grid = np.array(grid)
    ax.imshow(grid, cmap=arc_cmap, norm=norm)
    ax.set_title(title, fontsize=11, fontweight='bold')
    ax.set_xticks(np.arange(-0.5, grid.shape[1], 1), minor=True)
    ax.set_yticks(np.arange(-0.5, grid.shape[0], 1), minor=True)
    ax.grid(which='minor', color='#555555', linestyle='-', linewidth=1)
    ax.set_xticks([]); ax.set_yticks([])

def plot_ttt_results(task_list=TTT_TASKS, save_name=TTT_EVAL_SAVE_NAME, num_each=TTT_NUM_EACH, data_root=DATA_ROOT):
    task_type = data_root.split("/")[-1]
    for task_id in task_list:
        gt_path = f"raw_data/{task_type}/data/evaluation/{task_id}.json"
        if not os.path.exists(gt_path):
            print(f"✗ ground truth missing for {task_id}: {gt_path}")
            continue
        with open(gt_path) as f:
            gt_data = json.load(f)

        merged = None
        for i in range(num_each):
            fp = f"outputs/{save_name}_attempt_{i}/{task_id}_predictions.json"
            if not os.path.exists(fp):
                continue
            with open(fp) as f:
                d = json.load(f)
            if merged is None:
                merged = {k: list(v) for k, v in d.items()}
            else:
                for k, v in d.items():
                    merged.setdefault(k, [])
                    merged[k] += v
        if merged is None:
            print(f"⚠️ no predictions found for {task_id}")
            continue

        for idx_str, preds in merged.items():
            idx = int(idx_str)
            case = gt_data["test"][idx]
            mv = get_majority_vote(preds)
            pred_grid = mv[0]["prediction"] if mv else np.zeros_like(case["input"]).tolist()
            is_exact = pred_grid == case.get("output")

            fig, axs = plt.subplots(1, 3, figsize=(14, 4))
            status = "MATCH" if is_exact else "MISMATCH"
            fig.suptitle(f"Task ID: {task_id} (Test Instance {idx}) — {status}", fontsize=13, fontweight='bold', y=1.05)
            plot_grid(axs[0], case["input"], "True Input Grid (From Source)")
            plot_grid(axs[1], case.get("output", np.zeros_like(case["input"])), "True Target (From Source)")
            plot_grid(axs[2], pred_grid, "Your Model's Prediction")
            plt.tight_layout(); plt.show()

plot_ttt_results()
